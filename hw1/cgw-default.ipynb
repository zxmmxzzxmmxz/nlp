# %% [markdown]
# # Homework: Competitive Grammar Writing

# %% [markdown]
# ## Development of S1.gr
#
# To develop S1.gr which would be used to generate grammars, the base output that we would want from _S1.gr_ would be to output sentences that are potentially difficult for other teams to parse. To do this, it was decided that a
# custom grammar should be written from scratch to generate these. As a custom grammar would not be able to be developed rigidly in little time, it would likely be able to generate weird sentences.
#
# Using this approach in mind, S1.gr was developed completely custom by hand. To develop _S1.gr_, it was decided that **example_sentences.txt** would be the baseline used when developing _S1.gr_.
#
# When developing _S1.gr_, the main approach used was a recursive approach, in which every "appropriate" sentence would be defined as a **_Phrase_** and everything else would be a bunch of **_Phrase_** constructs recursively joined together.
#
# In example, lets take a look at a sentence from **example_sentences.txt**:
#
# > Arthur will have been riding for eight nights .
#
# Over here, the phrase,
#
# > riding for eight nights .
#
# Is a valid sentence and could very well be generated to be passed off as a regular sentence. As such, it should register as a **_Phrase_** construct. Moving on, the beginning of the sentence,
#
# > Arthur will have been
#
# Is also a valid phrase in some contexts of English. As a result, it will also be registered as a **_Phrase_** construct. Due to this, a construct that manually joins two **_Phrase_** constructs was also made, which is called a **_ComplexPhrase_** construct.
#
# _Note: all "constructs" are essentially Non-Terminal rules._
#
# ### Handling Conjunctions
#
# Due to already taking the approach of wanting to recursively define each valid part of a sentence as a construct in order to recursively parse a sentence, the next question would be what of conjunctions?
#
# Let us consider another sentence from **example_sentences.txt**:
#
# > Arthur rode and drank from his chalice .
#
# Following the previous logic laid out, one might expect to parse
#
# > Arthur rode
#
# and
#
# > drank from his chalice
#
# as **_Phrase_** constructs joined by a conjunction. However, doing so would give problems as conjunctions can be used arbitrarily many times in a sentence. As a result, with our current approach, we would end up having to define _arbitrarily many layers of_ **_ComplexPhrase_** _constructs in order to parse such sentences._ As a result, we take a different approach, which is by making a rule/construct that takes in a form of _(conjunction) (Phrase)_.
#
# This rule is defined as **_APhrase_** in _S1.gr_. What we essentially do is that we expand a **_Phrase_** to be able to take in a subphrase and any sort of **_APhrase_**. As a result, we will be able to parse arbitrarily many conjunctions as possible as they would all just be registered as **_APhrase_** constructs.
#
# ### How about the rest of grammar constructs that are too minor to be phrases?
#
# The rest of the constructs were made as per sentences in **example_sentences.txt**. As we based the custom grammar off the file, we made all the necessary constructs into _Non-Terminals_ that **_Phrase_** would consume in some form or manner.
#
# Examples of these would be constructs like
#
# > ...from his...
#
# > ...for eight nights...
#
# and so on. These are all tinier frequently-used constructs in the form of grammar rules like _(Preposition)(Pronoun)_ etc which are made as necessary as they appear in sentences from **example_sentences.txt**. As we are basing our custom grammar to be made off such a small amount of sentences, naturally some relations would not exist when they should, but that is of no matter, as the primary goal of _S1.gr_ is to be used to generate sentences that would be potentially difficult for other teams to parse.

# %% [markdown]
# ## The Development of S2.gr (parsing grammars)
#
# The grammars in S2 are auto-generated by training on devset.trees, marked example-sentences.txt, and some other resources all together.
#
# See following the code to read in trees, transform them to CNF, and extract grammars out.

# %%
from nltk import tree

class Tree:
    _trees = []
    _root = None

    def __init__(self, sentence):
        while sentence.find("(") != -1:
            left_bracket_index = sentence.find("(")
            right_bracket_index = left_bracket_index
            number_of_open_brackets = 1
            for (i, each_char) in enumerate(sentence[left_bracket_index + 1:]):
                if each_char == '(':
                    number_of_open_brackets += 1
                elif each_char == ')':
                    number_of_open_brackets -= 1
                    if number_of_open_brackets == 0:
                        right_bracket_index = i + 1
                        break
            self._root = self.analyze_grammars(sentence[left_bracket_index: left_bracket_index + right_bracket_index + 1], True)
            self._trees.append(self.analyze_grammars(sentence[left_bracket_index: left_bracket_index + right_bracket_index + 1], True))
            sentence = sentence[left_bracket_index + right_bracket_index + 1:]

    def transformToCNF(self, sentence):
        t = tree.Tree.fromstring(sentence, remove_empty_top_bracketing=True)

        # convert the tree to CNF
        t.chomsky_normal_form()
        return str(t)

    # should return a tree's root node
    def analyze_grammars(self, sentence, top):
        #print(sentence)
        sentence = self.transformToCNF(sentence)
        #print("after CNF transform")
        #print(sentence)
        if len(sentence.split()) == 2:
            # this is a terminal grammar segment
            terminal_parts = sentence.replace("(", " ").replace(")", " ").split()
            if not terminal_parts:
                return None
            if terminal_parts[0] == terminal_parts[1]:
                terminal_parts[0] *= 2
            new_node = GrammarNode(terminal_parts[0], terminal_parts[1])
            new_node.set_is_terminal(True)
            return new_node

        # remove first ( and last )
        sentence_without_out_most_bracket = sentence[sentence.find("(") + 1: sentence.rfind(")")]
        # split it
        # first token is left hand side
        left_side = sentence_without_out_most_bracket.split()[0]
        # slice the next grammar by first ( and first ) until no more (
        right_side = []
        temp_sentence = sentence_without_out_most_bracket
        while temp_sentence.find("(") != -1:
            left_bracket_index = temp_sentence.find("(")
            right_bracket_index = left_bracket_index
            number_of_open_brackets = 1
            for (i, each_char) in enumerate(temp_sentence[left_bracket_index + 1:]):
                if each_char == '(':
                    number_of_open_brackets += 1
                elif each_char == ')':
                    number_of_open_brackets -= 1
                    if number_of_open_brackets == 0:
                        right_bracket_index = i + 1
                        break
            to_append = self.analyze_grammars(temp_sentence[left_bracket_index: left_bracket_index + right_bracket_index + 1],False)
            if to_append is not None:
                right_side.append(to_append)
            temp_sentence = temp_sentence[left_bracket_index + right_bracket_index + 1:]

        new_node = GrammarNode(left_side, right_side)
        if top:
            new_node = GrammarNode("S1", [new_node])
        return new_node

    def dump_to_grammars(self):
        grammars = {}
        for each_tree in self._trees:
            self.dump_to_grammars_internal(each_tree, grammars)
        return grammars

    def dump_to_grammars_internal(self, node, grammars):
        if node.is_terminal():
            left = node.get_left_hand_side()
            right = node.get_right_hand_side()
            a_grammar = Grammar(left, right)
            if grammars.get(a_grammar) is None:
                #uncommenting these two lines will remove terminal grammars from the generated grammar file
                grammars[a_grammar] = 1
                grammars[a_grammar] = 0  #this line
            else:
                grammars[a_grammar] += 1
                grammars[a_grammar] = 0  #this line
            return

        left = node.get_left_hand_side()
        right = " ".join(map(lambda n: n.get_left_hand_side(), node.get_right_hand_side()))
        a_grammar = Grammar(left, right)
        if grammars.get(a_grammar) is None:
            grammars[a_grammar] = 1
            #uncommenting these two lines will remove non-terminal grammars from the generated file
            #grammars[a_grammar] = 0      #this line
        else:
            grammars[a_grammar] += 1
            #grammars[a_grammar] = 0       #this line
        for each in node.get_right_hand_side():
            self.dump_to_grammars_internal(each, grammars)




class GrammarNode:
    _left_hand_side = None
    _right_hand_side = []
    _isTerminal = False

    def __init__(self, left_hand_side=None, right_hand_side=[]):
        self._left_hand_side = left_hand_side
        self._right_hand_side = right_hand_side

    def set_left_hand_side(self, left_hand_side):
        self._left_hand_side = left_hand_side

    def set_right_hand_side(self, right_hand_side):
        self._right_hand_side = right_hand_side

    def set_is_terminal(self, is_terminal):
        self._isTerminal = is_terminal

    def get_left_hand_side(self):
        return self._left_hand_side

    def get_right_hand_side(self):
        return self._right_hand_side

    def is_terminal(self):
        return self._isTerminal

    def attach_node(self, node):
        self._children.push(node)

class Grammar:
    _left = ""
    _right = ""
    _prob = -1

    def __init__(self, left, right):
        self._left = left
        self._right = right

    def __hash__(self):
        return hash((self._left, self._right))

    def __eq__(self, other):
        return other is not None and self._left == other._left and self._right == other._right

    def __str__(self):
        return self._left + "  " + self._right


with open("devset.trees", "r") as f:
    sentences = ''.join(f.readlines())
f.close()

stuff = Tree(sentences)
grammars_with_count = stuff.dump_to_grammars()

left_set = set()
for key in grammars_with_count.keys():
    left_set.add(key._left)

for each_left in left_set:
    filtered_keys = {k:v for (k,v) in grammars_with_count.items() if k._left == each_left}
    total_count = 0
    for each in filtered_keys:
        total_count += grammars_with_count.get(each)
    # for grammar_to_update in filtered_keys:
    #     grammar_to_update._prob = grammars_with_count.get(grammar_to_update) / float(total_count)

    
##generated file will have extracted grammars
##see comments in method dump_to_grammars_internal() to see how to change types of grammars to be generated
with open("NT.gr", "w") as wf:
    for item in grammars_with_count.items():
        if item[1] is not 0:
            wf.write(str(item[1]) + " " + str(item[0]) + "\n")
wf.close()

with open("T.gr", "r") as wf:
    for line in wf.readlines():
        print(line)
wf.close()
# Out:
# 1 NNP  Whoa
#
# 9 EX  there
#
# 159 .  !
#
# 3 NN  Halt
#
# 10 WP  Who
#
# 1 VBZ  goes
#
# 4 RB  there
#
# 90 .  ?
#
# 11 PRP  It
#
# 37 VBZ  is
#
# 78 PRP  I
#
# 233 ,,  ,
#
# 18 NNP  Arthur
#
# 1 NN  son
#
# 60 IN  of
#
# 1 NNP  Uther
#
# 1 NNP  Pendragon
#
# 11 IN  from
#
# 97 DT  the
#
# 8 NN  castle
#
# 11 NNP  Camelot
#
# 207 ..  .
#
# 10 NNP  King
#
# 8 NNP  Britons
#
# 1 NN  defeator
#
# 1 NNP  Saxons
#
# 1 NN  sovereign
#
# 12 DT  all
#
# 2 NNP  England
#
# 1 VB  Pull
#
# 2 JJ  other
#
# 12 CD  one
#
# 10 VBP  am
#
# 13 CC  And
#
# 17 DT  this
#
# 16 PRP$  my
#
# 1 NN  trusty
#
# 1 NN  servant
#
# 3 NNP  Patsy
#
# 15 PRP  We
#
# 12 VBP  have
#
# 2 VBN  ridden
#
# 1 NN  length
#
# 42 CC  and
#
# 1 NN  breadth
#
# 4 NN  land
#
# 36 IN  in
#
# 2 NN  search
#
# 7 NNS  knights
#
# 9 WP  who
#
# 6 MD  will
#
# 7 VB  join
#
# 15 PRP  me
#
# 2 NN  court
#
# 2 MD  must
#
# 1 VB  speak
#
# 8 IN  with
#
# 27 PRP$  your
#
# 3 NN  lord
#
# 4 NN  master
#
# 25 WP  What
#
# 1 VBP  ridden
#
# 12 IN  on
#
# 78 DT  a
#
# 1 NN  horse
#
# 9 UH  Yes
#
# 3 NNP  You're
#
# 1 VBG  using
#
# 2 NNS  coconuts
#
# 1 NNP  You've
#
# 9 VBD  got
#
# 3 CD  two
#
# 1 JJ  empty
#
# 1 NNS  halves
#
# 6 NN  coconut
#
# 76 PRP  you
#
# 4 VBP  're
#
# 1 JJ  bangin
#
# 1 ''  'em
#
# 2 RB  together
#
# 7 RB  So
#
# 1 IN  since
#
# 1 NNS  snows
#
# 2 NN  winter
#
# 1 VBN  covered
#
# 5 IN  through
#
# 1 NN  kingdom
#
# 2 NNP  Mercea
#
# 42 :  --
#
# 1 WRB  Where
#
# 5 MD  'd
#
# 3 VB  get
#
# 1 VBD  found
#
# 5 PRP  them
#
# 1 IN  Found
#
# 2 IN  In
#
# 10 DT  The
#
# 8 POS  's
#
# 1 JJ  tropical
#
# 27 VBP  do
#
# 2 VB  mean
#
# 28 RB  Well
#
# 1 JJ  temperate
#
# 1 NN  zone
#
# 4 NN  swallow
#
# 3 MD  may
#
# 1 VB  fly
#
# 1 RB  south
#
# 1 NN  sun
#
# 3 CC  or
#
# 1 NN  house
#
# 1 NN  martin
#
# 1 NN  plumber
#
# 2 VB  seek
#
# 1 NN  warmer
#
# 1 NNS  climes
#
# 1 RB  yet
#
# 3 DT  these
#
# 18 VBP  are
#
# 30 RB  not
#
# 1 NNS  strangers
#
# 53 TO  to
#
# 4 PRP$  our
#
# 2 NNP  Are
#
# 1 VBG  suggesting
#
# 1 NN  migrate
#
# 4 RB  Not
#
# 13 IN  at
#
# 12 PRP  they
#
# 7 MD  could
#
# 22 VB  be
#
# 2 VBN  carried
#
# 2 JJ  swallow
#
# 1 VBG  carrying
#
# 1 VB  grip
#
# 22 PRP  it
#
# 11 IN  by
#
# 1 NN  husk
#
# 33 VBZ  's
#
# 2 NN  question
#
# 1 WRB  where
#
# 14 PRP  he
#
# 1 VBZ  grips
#
# 2 JJ  simple
#
# 1 JJ  weight
#
# 1 NNS  ratios
#
# 11 DT  A
#
# 1 CD  five
#
# 1 NN  ounce
#
# 1 NN  bird
#
# 2 VB  carry
#
# 1 CD  1
#
# 1 NN  pound
#
# 2 VBZ  does
#
# 28 RB  n't
#
# 1 VB  matter
#
# 3 MD  Will
#
# 7 VB  go
#
# 3 VB  tell
#
# 13 IN  that
#
# 2 NNP  Court
#
# 8 RB  here
#
# 2 NNP  Listen
#
# 2 NN  order
#
# 1 VB  maintain
#
# 1 NN  air
#
# 38 :  -
#
# 1 NN  speed
#
# 1 NN  velocity
#
# 1 NNS  needs
#
# 1 VB  beat
#
# 2 PRP$  its
#
# 1 NNS  wings
#
# 1 CD  43
#
# 3 NNS  times
#
# 1 DT  every
#
# 3 JJ  second
#
# 2 RB  right
#
# 1 NN  Please
#
# 1 VBP  Am
#
# 17 NNP  I'm
#
# 1 JJ  interested
#
# 8 DT  an
#
# 3 JJ  African
#
# 29 UH  Oh
#
# 4 UH  yeah
#
# 1 RB  maybe
#
# 12 CC  but
#
# 1 JJ  European
#
# 2 WDT  that
#
# 1 NN  point
#
# 1 VBP  agree
#
# 10 DT  that
#
# 20 :  ...
#
# 2 VB  ask
#
# 5 IN  if
#
# 1 VBZ  wants
#
# 3 CC  But
#
# 11 RB  then
#
# 2 NN  course
#
# 2 NNS  swallows
#
# 1 JJ  migratory
#
# 1 IN  So
#
# 1 VB  bring
#
# 2 RB  back
#
# 2 RB  anyway
#
# 1 WRB  Wait
#
# 1 NN  minute
#
# 1 VBG  supposing
#
# 1 VBD  carried
#
# 8 DT  No
#
# 10 VB  have
#
# 1 NN  line
#
# 1 NN  simple
#
# 2 PRP  They
#
# 7 RB  just
#
# 2 VB  use
#
# 1 JJ  standard
#
# 1 NN  creeper
#
# 2 VBD  held
#
# 1 IN  under
#
# 1 NN  dorsal
#
# 1 VBG  guiding
#
# 1 NNS  feathers
#
# 3 WRB  why
#
# 1 VBG  Bring
#
# 5 RP  out
#
# 5 JJ  dead
#
# 2 RB  Here
#
# 3 CD  nine
#
# 2 NN  pence
#
# 1 NN  Nothing
#
# 2 VBZ  says
#
# 8 PRP  He
#
# 2 RB  soon
#
# 5 RB  very
#
# 1 JJ  ill
#
# 1 VBG  getting
#
# 1 RB  better
#
# 11 MD  'll
#
# 1 VBN  stone
#
# 1 NN  moment
#
# 6 VBP  can't
#
# 4 VB  take
#
# 11 PRP  him
#
# 7 IN  like
#
# 1 IN  against
#
# 1 NNS  regulations
#
# 3 VB  want
#
# 1 NN  cart
#
# 1 JJ  such
#
# 1 NN  baby
#
# 3 VBP  feel
#
# 1 JJ  fine
#
# 8 PRP  us
#
# 2 NN  favor
#
# 5 MD  can
#
# 1 VB  hang
#
# 2 IN  around
#
# 1 NN  couple
#
# 1 NNS  minutes
#
# 1 MD  wo
#
# 1 RB  long
#
# 1 NNP  Naaah
#
# 1 NNP  Robinson
#
# 4 VBP  've
#
# 1 VBN  lost
#
# 1 NN  today
#
# 2 WRB  when
#
# 1 JJ  next
#
# 2 NN  round
#
# 2 NNP  Thursday
#
# 2 VBP  think
#
# 17 IN  for
#
# 1 NN  walk
#
# 2 VBG  fooling
#
# 1 NN  anyone
#
# 1 NN  y'
#
# 2 VBP  know
#
# 5 NNP  Look
#
# 1 NN  something
#
# 10 VB  do
#
# 2 JJ  happy
#
# 4 NNP  Ah
#
# 1 NNS  thanks
#
# 1 RB  much
#
# 1 VB  See
#
# 7 RB  Right
#
# 4 VB  know
#
# 1 RB  Must
#
# 7 NN  king
#
# 2 WRB  Why
#
# 2 VBZ  has
#
# 3 VBN  got
#
# 1 VB  shit
#
# 2 IN  over
#
# 2 NNP  Old
#
# 2 NN  woman
#
# 2 NN  Man
#
# 1 NNP  Man
#
# 3 NN  sorry
#
# 1 VBD  knight
#
# 1 JJ  live
#
# 2 VBD  thirty
#
# 2 CD  seven
#
# 2 JJ  old
#
# 2 VB  call
#
# 4 ``  `
#
# 11 ''  '
#
# 2 VB  say
#
# 4 NNP  Dennis
#
# 7 POS  '
#
# 13 VBD  did
#
# 5 VBD  were
#
# 2 VBN  called
#
# 1 VB  bother
#
# 1 VB  find
#
# 3 IN  about
#
# 1 NN  behind
#
# 1 VBD  looked
#
# 1 VBP  object
#
# 1 RB  automatically
#
# 1 VB  treat
#
# 1 NN  inferior
#
# 1 VBP  AM
#
# 3 VBG  king
#
# 2 NN  eh
#
# 3 JJ  nice
#
# 1 DT  An
#
# 5 WRB  how
#
# 3 VB  eh
#
# 2 IN  By
#
# 1 NN  exploitin
#
# 1 NNS  workers
#
# 1 NN  angin
#
# 1 JJ  outdated
#
# 1 NN  imperialist
#
# 1 NN  dogma
#
# 2 WDT  which
#
# 1 VBZ  perpetuates
#
# 1 JJ  economic
#
# 1 JJ  social
#
# 1 NNS  differences
#
# 1 NN  society
#
# 6 IN  If
#
# 1 RB  ever
#
# 2 VBG  going
#
# 1 DT  any
#
# 1 NN  progress
#
# 4 DT  some
#
# 1 RB  lovely
#
# 1 VBP  filth
#
# 1 RP  down
#
# 1 NN  d'
#
# 2 WRB  How
#
# 1 VB  good
#
# 1 NN  lady
#
# 2 NNS  Britons
#
# 17 PRP  we
#
# 1 IN  we're
#
# 7 VBD  had
#
# 1 VBD  thought
#
# 1 JJ  autonomous
#
# 1 NN  collective
#
# 2 PRP  yourself
#
# 4 NNP  We're
#
# 1 NN  living
#
# 1 NN  dictatorship
#
# 1 PRP  self
#
# 1 VBG  perpetuating
#
# 1 NN  autocracy
#
# 1 NN  working
#
# 1 NNS  classes
#
# 2 VBP  go
#
# 1 VBG  bringing
#
# 1 NN  class
#
# 4 IN  into
#
# 2 RB  again
#
# 6 DT  That
#
# 11 WP  what
#
# 1 JJ  only
#
# 3 NNS  people
#
# 2 MD  would
#
# 1 NNP  Please
#
# 1 VB  please
#
# 5 JJ  good
#
# 1 NN  haste
#
# 1 VBZ  lives
#
# 1 NN  live
#
# 3 RB  Then
#
# 2 VBD  told
#
# 1 JJ  anarcho
#
# 1 NN  syndicalist
#
# 1 NN  commune
#
# 2 VBP  take
#
# 1 VBZ  turns
#
# 1 VB  act
#
# 5 IN  as
#
# 1 NN  sort
#
# 1 JJ  executive
#
# 2 NN  officer
#
# 1 NN  week
#
# 3 PDT  all
#
# 1 NN  decision
#
# 1 VBN  ratified
#
# 1 JJ  special
#
# 1 JJ  biweekly
#
# 1 NN  meeting
#
# 5 VBP  see
#
# 2 NN  majority
#
# 3 NN  case
#
# 1 RB  purely
#
# 1 JJ  internal
#
# 1 NNS  affairs
#
# 3 NNP  Be
#
# 5 JJ  quiet
#
# 1 NNS  thirds
#
# 2 JJR  more
#
# 1 NN  Order
#
# 6 VB  think
#
# 2 VB  vote
#
# 12 PRP  You
#
# 1 NNS  kings
#
# 1 NN  ow
#
# 1 VB  become
#
# 1 NNP  Lady
#
# 1 NNP  Lake
#
# 4 PRP$  her
#
# 2 NN  arm
#
# 1 NN  clad
#
# 1 NN  purest
#
# 1 VBG  shimmering
#
# 1 NN  samite
#
# 1 RB  aloft
#
# 2 NNP  Excalibur
#
# 1 NN  bosom
#
# 3 NN  water
#
# 1 NN  signifying
#
# 1 NNP  Divine
#
# 1 NNP  Providence
#
# 8 VBD  was
#
# 2 JJ  strange
#
# 1 NNS  women
#
# 1 VBG  lying
#
# 1 NNS  ponds
#
# 1 VBG  distributing
#
# 1 NNS  swords
#
# 11 DT  no
#
# 1 NN  basis
#
# 3 NN  system
#
# 1 NN  government
#
# 1 NNP  Supreme
#
# 2 NN  executive
#
# 2 NN  power
#
# 1 VBZ  derives
#
# 1 NN  mandate
#
# 1 NNS  masses
#
# 1 JJ  farcical
#
# 1 JJ  aquatic
#
# 1 NN  ceremony
#
# 1 VB  expect
#
# 1 VB  wield
#
# 1 JJ  supreme
#
# 2 NN  cause
#
# 1 JJ  watery
#
# 1 NN  tart
#
# 1 VBD  threw
#
# 2 NN  sword
#
# 5 NNP  Shut
#
# 11 RP  up
#
# 1 VBP  mean
#
# 2 VBD  went
#
# 1 NN  sayin
#
# 1 NN  empereror
#
# 2 IN  because
#
# 1 JJ  moistened
#
# 1 NN  bint
#
# 1 VBN  lobbed
#
# 1 NN  scimitar
#
# 1 VB  put
#
# 6 RB  away
#
# 1 VB  shut
#
# 6 RB  now
#
# 2 NN  violence
#
# 2 NN  inherent
#
# 7 NNP  Come
#
# 1 VB  see
#
# 1 NN  HELP
#
# 1 VBG  being
#
# 1 VBN  repressed
#
# 1 NNP  Bloody
#
# 1 NN  peasant
#
# 1 JJ  give
#
# 1 NN  away
#
# 2 NNP  Did
#
# 1 RB  about
#
# 1 VBG  repressing
#
# 1 VBD  saw
#
# 1 VBP  fight
#
# 1 NN  strength
#
# 2 JJ  many
#
# 1 NNS  men
#
# 22 NNP  Sir
#
# 2 NNP  knight
#
# 1 VBP  seek
#
# 1 NN  finest
#
# 1 JJS  bravest
#
# 1 VBN  proved
#
# 3 JJ  worthy
#
# 5 :  ;
#
# 1 VBP  make
#
# 1 JJ  sad
#
# 2 NN  None
#
# 9 MD  shall
#
# 2 VB  pass
#
# 1 NN  quarrel
#
# 3 NN  knight
#
# 1 VB  cross
#
# 2 NN  bridge
#
# 2 VB  die
#
# 1 VBP  command
#
# 1 VB  stand
#
# 2 RB  aside
#
# 1 VBP  move
#
# 2 NN  man
#
# 6 RB  Now
#
# 1 VBP  stand
#
# 1 NN  adversary
#
# 1 NNP  Tis
#
# 2 NN  scratch
#
# 1 PRP$  Your
#
# 4 RP  off
#
# 3 NNP  I've
#
# 1 JJR  worse
#
# 1 VBP  liar
#
# 1 VB  Come
#
# 1 VBP  pansy
#
# 1 NN  Victory
#
# 2 JJ  mine
#
# 1 VBP  thank
#
# 1 JJ  thee
#
# 5 NNP  Lord
#
# 1 JJ  thy
#
# 1 NN  merc
#
# 2 VBP  Have
#
# 1 RB  indeed
#
# 2 JJ  brave
#
# 1 NN  fight
#
# 1 RB  enough
#
# 1 VBP  stupid
#
# 1 RB  bastard
#
# 1 NNS  arms
#
# 1 VBD  left
#
# 2 NN  Look
#
# 1 RB  Just
#
# 1 JJ  flesh
#
# 1 NN  wound
#
# 1 NN  stop
#
# 1 NN  Chicken
#
# 1 NN  leg
#
# 1 NN  ere
#
# 1 VB  bleed
#
# 1 JJ  invincible
#
# 2 VB  You're
#
# 1 NN  loony
#
# 1 NNP  Black
#
# 4 NNP  Knight
#
# 1 RB  always
#
# 1 VBP  triumphs
#
# 2 DT  All
#
# 4 NN  right
#
# 1 NN  draw
#
# 2 UH  oh
#
# 1 VBG  running
#
# 1 VBP  yellow
#
# 1 NNS  bastards
#
# 1 VBG  coming
#
# 1 VB  bite
#
# 1 NNS  legs
#
# 11 NN  witch
#
# 1 NNP  We've
#
# 1 VBN  found
#
# 1 MD  might
#
# 3 VB  burn
#
# 8 PRP  her
#
# 7 NNP  Burn
#
# 4 NN  Burn
#
# 7 PRP  she
#
# 2 PRP  She
#
# 1 VBZ  looks
#
# 1 NNP  Bring
#
# 1 NN  forward
#
# 1 VBN  dressed
#
# 1 VBD  dressed
#
# 1 RB  No
#
# 1 JJ  nose
#
# 1 JJ  false
#
# 3 NN  nose
#
# 1 NN  hat
#
# 1 NN  Witch
#
# 1 VB  dress
#
# 1 RB  yes
#
# 2 UH  yes
#
# 4 NN  bit
#
# 1 NN  wart
#
# 1 VBZ  makes
#
# 1 VBD  turned
#
# 2 NN  newt
#
# 1 RBR  better
#
# 1 NN  anyway
#
# 2 JJ  Quiet
#
# 1 EX  There
#
# 4 NNS  ways
#
# 1 VBG  telling
#
# 2 IN  whether
#
# 1 IN  Are
#
# 1 VB  Tell
#
# 4 NNS  witches
#
# 1 VBP  burn
#
# 2 RB  apart
#
# 1 RBR  More
#
# 1 NN  Wood
#
# 1 NNP  B
#
# 3 VBN  made
#
# 4 NN  wood
#
# 3 JJ  Good
#
# 2 NN  yeah
#
# 1 VB  Build
#
# 5 IN  out
#
# 1 NNP  Aah
#
# 2 RB  also
#
# 1 VB  build
#
# 1 NNS  bridges
#
# 1 NN  stone
#
# 1 NNP  Does
#
# 1 VB  sink
#
# 2 VBZ  floats
#
# 1 VB  Throw
#
# 2 NN  pond
#
# 1 NN  Bread
#
# 1 NNS  Apples
#
# 1 RB  Very
#
# 1 JJ  small
#
# 1 NNS  rocks
#
# 1 NN  Cider
#
# 1 NNP  Great
#
# 1 NN  gravy
#
# 1 NNS  Cherries
#
# 1 NN  Mud
#
# 1 NNS  Churches
#
# 1 NNS  churches
#
# 1 NNP  Lead
#
# 1 JJ  lead
#
# 2 NN  duck
#
# 1 NNP  Oooh
#
# 1 RB  Exactly
#
# 1 RB  logically
#
# 1 NN  she.
#
# 1 VBZ  weighs
#
# 1 JJ  same
#
# 1 RB  therefore
#
# 1 JJR  larger
#
# 1 NNS  scales
#
# 1 VB  remove
#
# 1 NNS  supports
#
# 1 JJ  fair
#
# 1 NN  cop
#
# 5 RB  so
#
# 1 RB  wise
#
# 1 NN  science
#
# 2 PRP$  My
#
# 4 NN  liege
#
# 2 VB  come
#
# 8 NNP  Round
#
# 8 NNP  Table
#
# 1 VBN  honored
#
# 1 NN  name
#
# 4 NNP  Bedemir
#
# 1 NN  leige
#
# 1 VBP  dub
#
# 1 NN  wise
#
# 1 JJ  first
#
# 1 JJ  illustrious
#
# 2 NNS  names
#
# 1 VB  follow
#
# 1 ::  :
#
# 3 NNP  Launcelot
#
# 3 NNP  Brave
#
# 1 VBD  Galahad
#
# 1 NNP  Pure
#
# 9 NNP  Robin
#
# 2 RB  quite
#
# 2 VB  brave
#
# 1 NN  Launcelot
#
# 2 RB  nearly
#
# 1 VBN  fought
#
# 1 NNP  Dragon
#
# 1 NNP  Agnor
#
# 1 VBN  stood
#
# 1 JJ  vicious
#
# 1 NNP  Chicken
#
# 1 NNP  Bristol
#
# 1 RB  personally
#
# 1 JJ  wet
#
# 1 PRP  himself
#
# 1 NNP  Battle
#
# 1 NNP  Badon
#
# 1 NNP  Hill
#
# 1 RB  aptly
#
# 1 VBN  named
#
# 1 VBG  appearing
#
# 1 NN  film
#
# 1 RB  Together
#
# 1 VBD  formed
#
# 1 NN  band
#
# 1 WP$  whose
#
# 1 NNS  deeds
#
# 1 VBN  retold
#
# 1 IN  throughout
#
# 1 NNS  centuries
#
# 2 NNP  Knights
#
# 1 NN  Earth
#
# 1 VBN  banana
#
# 1 NN  shaped
#
# 2 DT  This
#
# 3 JJ  new
#
# 1 NN  learning
#
# 1 IN  amazes
#
# 1 RB  Explain
#
# 1 JJ  sheeps'
#
# 1 NNS  bladders
#
# 1 VBN  employed
#
# 1 VB  prevent
#
# 1 NNS  earthquakes
#
# 1 RB  certainly
#
# 2 NN  sir
#
# 2 NN  Camelot
#
# 3 RB  only
#
# 1 NN  model
#
# 1 NN  Shhh
#
# 2 NNS  Knights
#
# 1 VBP  bid
#
# 1 VBP  welcome
#
# 1 NN  home
#
# 1 VB  Let
#
# 1 VB  ride
#
# 1 NN  table
#
# 1 VBP  dance
#
# 1 NN  e'er
#
# 2 NN  we're
#
# 4 JJ  able
#
# 1 NNS  routines
#
# 1 NN  parlour
#
# 1 NNS  scenes
#
# 1 IN  With
#
# 1 NN  footwork
#
# 1 NN  impecc
#
# 1 JJ  Able
#
# 1 VBP  dine
#
# 3 RB  well
#
# 1 VBP  eat
#
# 1 JJ  ham
#
# 1 NN  jam
#
# 1 VB  spam
#
# 3 NN  lot
#
# 2 PRP$  Our
#
# 1 NNS  shows
#
# 1 NN  mid
#
# 1 IN  Though
#
# 1 JJ  we're
#
# 1 VBN  given
#
# 1 NNS  rhymes
#
# 1 JJ  unsing
#
# 1 JJ  fat
#
# 1 VBG  sing
#
# 1 NN  diaphragm
#
# 1 JJ  tough
#
# 1 RB  Quite
#
# 1 JJ  indefatigable
#
# 1 IN  Between
#
# 1 NNS  quests
#
# 1 VBP  sequin
#
# 1 NNS  vests
#
# 1 VB  impersonate
#
# 1 NNP  Clark
#
# 1 NNP  Gable
#
# 1 RB  too
#
# 1 JJ  loud
#
# 1 VB  push
#
# 1 NN  pram
#
# 1 NN  thought
#
# 2 VB  let
#
# 2 PRP  's
#
# 3 JJ  silly
#
# 1 NN  place
#
# 1 VB  grovel
#
# 1 NN  thing
#
# 1 RB  stand
#
# 1 VBG  groveling
#
# 1 NNP  Sorry
#
# 1 VB  apologize
#
# 1 DT  Every
#
# 3 NN  time
#
# 1 VBP  try
#
# 3 VB  talk
#
# 2 NN  someone
#
# 1 JJ  "
#
# 3 NN  "
#
# 2 NNP  "
#
# 1 VBP  forgive
#
# 2 VBG  doing
#
# 1 VBG  averting
#
# 2 NNS  eyes
#
# 2 JJ  oh
#
# 1 DT  those
#
# 1 JJ  miserable
#
# 1 NNP  Psalms
#
# 1 JJ  depressing
#
# 1 VBZ  knock
#
# 2 NN  task
#
# 1 VB  make
#
# 1 NN  example
#
# 2 JJ  dark
#
# 2 NN  idea
#
# 1 NNP  Course
#
# 1 NN  Behold
#
# 4 NNP  Holy
#
# 7 NNP  Grail
#
# 2 JJ  sacred
#
# 1 NN  purpose
#
# 1 NNP  Quest
#
# 2 NN  blessing
#
# 2 NNP  God
#
# 1 VBN  praised
#
# 1 NN  Hallo
#
# 1 NN  Allo
#
# 1 VBN  zis
#
# 1 VBG  King
#
# 1 NNP  Master
#
# 1 NNP  Ruiz
#
# 1 FW  de
#
# 1 FW  lu
#
# 1 FW  la
#
# 1 NNP  Ramper
#
# 1 VB  sp
#
# 2 NNP  Go
#
# 2 VBN  been
#
# 1 VBN  charged
#
# 3 NN  quest
#
# 1 VB  give
#
# 2 NN  food
#
# 1 NN  shelter
#
# 1 NN  night
#
# 1 JJ  keen
#
# 3 NNP  Uh
#
# 3 RB  already
#
# 1 VBP  sure
#
# 2 JJ  um
#
# 1 RB  up
#
# 3 NN  look
#
# 1 IN  Of
#
# 2 JJ  English
#
# 1 NNS  types
#
# 3 JJ  French
#
# 1 JJ  outrageous
#
# 1 NN  accent
#
# 1 RB  silly
#
# 1 VB  Mind
#
# 2 JJ  own
#
# 1 NN  business
#
# 1 VB  show
#
# 1 NN  force
#
# 1 VB  frighten
#
# 1 NNP  English
#
# 1 SYM  pig
#
# 1 NNS  dogs
#
# 1 VB  boil
#
# 1 NNS  bottoms
#
# 1 NNS  sons
#
# 2 NN  person
#
# 1 VBP  blow
#
# 1 IN  so
#
# 1 NNS  kaniggets
#
# 1 NN  Thppppt
#
# 1 RBR  more
#
# 1 VBP  empty
#
# 1 VBN  headed
#
# 1 JJ  animal
#
# 1 IN  trough
#
# 1 NN  whopper
#
# 1 VBP  fart
#
# 1 JJ  general
#
# 1 NN  direction
#
# 1 VBP  mother
#
# 1 NN  hamster
#
# 1 NN  father
#
# 1 NN  smelt
#
# 1 NNS  eldeberries
#
# 1 VBZ  Is
#
# 1 RB  else
#
# 1 IN  up
#
# 1 VB  taunt
#
# 1 JJ  last
#
# 1 NN  chance
#
# 1 IN  than
#
# 1 JJ  reasonable
#
# 2 NNP  Fetchez
#
# 2 NNP  la
#
# 1 NNP  vache
#
# 1 NN  wha
#
# 1 NN  vache
#
# 1 VB  agree
#
# 1 NNS  commands
#
# 1 NNP  Jesus
#
# 1 NN  Christ
#
# 1 NN  Charge
#
# 1 NN  mother
#
# 2 VB  Run
#
# 1 NN  Thpppt
#
# 1 NNS  Fiends
#
# 1 VB  tear
#
# 1 NN  plan
#
# 1 NN  ce
#
# 1 VBZ  labon
#
# 1 NN  bunny
#
# 1 NNS  wha
#
# 2 JJ  un
#
# 2 NN  cadeau
#
# 1 JJ  present
#
# 1 JJ  oui
#
# 1 NN  oui
#
# 1 NN  hurry
#
# 1 SYM  wha
#
# 2 NN  let
#
# 1 VBZ  happens
#
# 3 UH  uh
#
# 2 NNP  Galahad
#
# 1 VBP  wait
#
# 1 IN  until
#
# 1 JJ  nightfall
#
# 1 VB  leap
#
# 2 NN  rabbit
#
# 1 VBG  taking
#
# 3 NN  surprise
#
# 1 RB  totally
#
# 1 JJ  unarmed
#
# 1 VBZ  leaps
#
# 1 VBZ  leap
#
# 2 NN  uh
#
# 3 NNP  Um
#
# 1 SYM  l
#
# 1 VBP  built
#
# 1 JJ  large
#
# 1 JJ  wooden
#
# 1 NN  badger
#
# 1 JJ  haw
#
# 2 NN  haw
#
# 1 NNS  Pictures
#
# 1 NNP  Schools
#
# 1 CD  8
#
# 1 NN  Action
#
# 1 NN  Defeat
#
# 1 VBZ  seems
#
# 1 RB  utterly
#
# 1 VBN  disheartened
#
# 1 NN  ferocity
#
# 1 NN  taunting
#
# 1 VBD  took
#
# 1 RB  completely
#
# 1 VBD  became
#
# 1 VBD  convinced
#
# 1 NN  strategy
#
# 1 VBN  required
#
# 1 VBN  brought
#
# 1 JJ  successful
#
# 1 NN  conclusion
#
# 1 VBG  having
#
# 1 VBN  consulted
#
# 14 PRP$  his
#
# 1 JJS  closest
#
# 1 VBD  decided
#
# 1 MD  should
#
# 1 VB  separate
#
# 1 RB  individually
#
# 1 NN  Greg
#
# 1 NNP  Tale
#
# 1 DT  each
#
# 1 PRP$  their
#
# 1 JJ  separate
#
# 2 VBD  rode
#
# 1 JJ  north
#
# 1 NN  forest
#
# 1 NNP  Ewing
#
# 1 VBN  accompanied
#
# 1 JJ  favorite
#
# 1 NNS  minstrels
#
# 1 RB  Bravely
#
# 1 JJ  bold
#
# 1 NN  forth
#
# 2 JJ  afraid
#
# 1 FW  o
#
# 1 VBN  killed
#
# 1 JJ  nasty
#
# 1 NN  brave
#
# 3 VBP  brave
#
# 1 JJS  least
#
# 1 VBD  scared
#
# 1 VBN  mashed
#
# 1 NN  pulp
#
# 1 CC  Or
#
# 1 VBD  gouged
#
# 1 NNS  elbows
#
# 1 VBN  broken
#
# 2 TO  To
#
# 1 NNS  kneecaps
#
# 1 NN  split
#
# 1 NN  body
#
# 2 VBD  burned
#
# 1 NN  limbs
#
# 1 VBD  hacked
#
# 1 VBD  mangled
#
# 1 PRP$  His
#
# 3 NN  head
#
# 1 VBN  smashed
#
# 1 NN  heart
#
# 1 NN  cut
#
# 1 NN  liver
#
# 1 VBD  removed
#
# 1 NNS  bowels
#
# 1 VBN  unplugged
#
# 1 NNS  nostrils
#
# 1 VBD  ripped
#
# 1 NN  bottom
#
# 1 NN  penis
#
# 1 JJ  enough
#
# 1 NN  music
#
# 1 NNS  lads
#
# 1 NNS  Looks
#
# 1 NN  dirty
#
# 1 NN  work
#
# 1 NN  afoot
#
# 1 NNP  Anarcho
#
# 1 NN  syndicalism
#
# 1 NN  way
#
# 1 VBG  preserving
#
# 2 NN  freedom
#
# 1 VB  forget
#
# 1 VBD  dropped
#
# 1 NN  mud
#
# 1 VBP  art
#
# 1 NN  thou
#
# 1 SYM  n
#
# 2 JJ  n
#
# 1 NN  nobody
#
# 2 RB  really
#
# 1 SYM  j
#
# 1 VBG  passing
#
# 1 VB  fight
#
# 1 NN  oo
#
# 2 NN  nothing
#
# 1 JJ  j
#
# 1 NN  j
#
# 1 NN  ust
#
# 1 VB  um
#
# 1 VB  p
#
# 1 NN  pass
#
# 1 VBD  afraid
#
# 1 NNP  W
#
# 1 RB  actually
#
# 3 VB  kill
#
# 1 NN  Shall
#
# 1 NNP  Well
#
# 1 VBD  shut
#
# 1 RB  Perhaps
#
# 1 JJ  quick
#
# 1 VBP  want
#
# 2 VB  cut
#
# 2 IN  off
#
# 1 VBG  Yapping
#
# 1 PRP$  You're
#
# 1 JJ  lucky
#
# 1 MD  You're
#
# 1 VB  next
#
# 1 VBP  snore
#
# 1 JJ  bad
#
# 1 NN  breath
#
# 1 VB  brush
#
# 1 NNS  teeth
#
# 1 VB  stop
#
# 1 NN  bitching
#
# 1 JJ  have
#
# 2 NN  tea
#
# 1 RB  first
#
# 2 NNS  biscuits

# %%
with open("NT.gr", "r") as wf:
    for line in wf.readlines():
        print(line)
wf.close()
# Out:
# 26 S1  INTJ
#
# 1 INTJ  NNP INTJ|<ADVP-.>
#
# 1 INTJ|<ADVP-.>  ADVP .
#
# 2 ADVP  EX
#
# 74 S1  NP
#
# 18 NP  NN .
#
# 37 S1  SBARQ
#
# 19 SBARQ  WHNP SBARQ|<SQ-.>
#
# 44 WHNP  WP
#
# 31 SBARQ|<SQ-.>  SQ .
#
# 8 SQ  VP
#
# 4 VP  VBZ ADVP
#
# 93 ADVP  RB
#
# 275 S1  S
#
# 89 S  NP S|<VP-.>
#
# 324 NP  PRP
#
# 113 S|<VP-.>  VP ..
#
# 2 VP  VBZ VP|<NP-PP>
#
# 27 VP|<NP-PP>  NP PP
#
# 1 NP  NP NP|<,-NP-,-NP-,>
#
# 1 NP|<,-NP-,-NP-,>  ,, NP|<NP-,-NP-,>
#
# 1 NP|<NP-,-NP-,>  NP NP|<,-NP-,>
#
# 80 NP  NNP
#
# 2 NP|<,-NP-,>  ,, NP|<NP-,>
#
# 2 NP|<NP-,>  NP ,,
#
# 61 NP  NP PP
#
# 54 NP  NN
#
# 173 PP  IN NP
#
# 14 NP  NNP NNP
#
# 102 NP  DT NN
#
# 1 NP  NP NP|<,-NP-,-ADJP-.>
#
# 25 NP  DT NNP
#
# 1 NP|<,-NP-,-ADJP-.>  ,, NP|<NP-,-ADJP-.>
#
# 1 NP|<NP-,-ADJP-.>  NP NP|<,-ADJP-.>
#
# 1 NP|<,-ADJP-.>  ,, NP|<ADJP-.>
#
# 5 NP|<ADJP-.>  ADJP .
#
# 4 ADJP  NN PP
#
# 33 S  VP .
#
# 34 VP  VB NP
#
# 2 NP  DT NP|<JJ-CD>
#
# 2 NP|<JJ-CD>  JJ CD
#
# 14 VP  VBP
#
# 55 S1  FRAG
#
# 1 FRAG  CC FRAG|<NP-NP-.>
#
# 1 FRAG|<NP-NP-.>  NP FRAG|<NP-.>
#
# 30 NP  DT
#
# 10 FRAG|<NP-.>  NP ..
#
# 1 NP  PRP$ NP|<NN-NN-NNP>
#
# 1 NP|<NN-NN-NNP>  NN NP|<NN-NNP>
#
# 1 NP|<NN-NNP>  NN NNP
#
# 14 VP  VBP VP
#
# 3 VP  VBN VP|<NP-PP>
#
# 1 NP  DT NP|<NN-CC-NN>
#
# 2 NP|<NN-CC-NN>  NN NP|<CC-NN>
#
# 4 NP|<CC-NN>  CC NN
#
# 9 NP  NP SBAR
#
# 30 NP  NNS
#
# 12 SBAR  WHNP S
#
# 69 S  VP
#
# 36 VP  MD VP
#
# 17 VP  VB VP|<NP-PP>
#
# 34 NP  PRP$ NN
#
# 16 VP  VB PP
#
# 1 NP  PRP$ NP|<NN-CC-NN>
#
# 1 SBARQ  WHNP SBARQ|<,-S-.>
#
# 1 SBARQ|<,-S-.>  ,, SBARQ|<S-.>
#
# 2 SBARQ|<S-.>  S .
#
# 11 VP  VBP PP
#
# 2 INTJ  UH .
#
# 52 S|<VP-.>  VP .
#
# 8 VP  VBG NP
#
# 8 FRAG  WP .
#
# 4 S  S S|<CC-S-.>
#
# 121 S  NP VP
#
# 18 VP  VBD NP
#
# 1 NP  CD NP|<JJ-NNS>
#
# 7 NP|<JJ-NNS>  JJ NNS
#
# 10 S|<CC-S-.>  CC S|<S-.>
#
# 24 S|<S-.>  S ..
#
# 1 VP  VBP VP|<JJ-NP-ADVP>
#
# 1 VP|<JJ-NP-ADVP>  JJ VP|<NP-ADVP>
#
# 10 VP|<NP-ADVP>  NP ADVP
#
# 1 NP  ''
#
# 3 S1  ADVP
#
# 2 ADVP  RB .
#
# 6 S  NP S|<VP-:>
#
# 12 S|<VP-:>  VP :
#
# 1 VP  VBN VP|<SBAR-,-PP-,-PP>
#
# 1 VP|<SBAR-,-PP-,-PP>  SBAR VP|<,-PP-,-PP>
#
# 17 SBAR  IN S
#
# 1 S  NP S|<VBN-NP>
#
# 10 NP  DT NNS
#
# 1 S|<VBN-NP>  VBN NP
#
# 1 VP|<,-PP-,-PP>  ,, VP|<PP-,-PP>
#
# 1 VP|<PP-,-PP>  PP VP|<,-PP>
#
# 1 VP|<,-PP>  ,, PP
#
# 1 PP  IN
#
# 4 SBARQ  WHADVP SBARQ|<SQ-.>
#
# 15 WHADVP  WRB
#
# 4 SQ  MD SQ|<NP-VP>
#
# 20 SQ|<NP-VP>  NP VP
#
# 3 VP  IN NP
#
# 2 S1  PP
#
# 1 PP  IN PP|<NP-.>
#
# 1 PP|<NP-.>  NP .
#
# 1 VP  POS ADJP
#
# 18 ADJP  JJ
#
# 10 SQ  VBP SQ|<NP-VP>
#
# 23 VP  VB
#
# 17 S  INTJ S|<,-NP-VP-.>
#
# 31 INTJ  RB
#
# 29 S|<,-NP-VP-.>  ,, S|<NP-VP-.>
#
# 50 S|<NP-VP-.>  NP S|<VP-.>
#
# 30 VP  VBZ NP
#
# 23 NP  DT NP|<JJ-NN>
#
# 35 NP|<JJ-NN>  JJ NN
#
# 1 S  S S|<RB-S-.>
#
# 1 VP  VB VP|<ADVP-PP>
#
# 4 VP|<ADVP-PP>  ADVP PP
#
# 8 NP  NP VP
#
# 3 NP  NP NP|<CC-NP>
#
# 4 NP|<CC-NP>  CC NP
#
# 2 NP  DT NP|<NN-NN>
#
# 6 NP|<NN-NN>  NN NN
#
# 2 NP  NN NNS
#
# 1 S|<RB-S-.>  RB S|<S-.>
#
# 1 VP  VBP VP|<RB-NP>
#
# 3 VP|<RB-NP>  RB NP
#
# 14 PP  TO NP
#
# 20 S1  SQ
#
# 3 SQ  NNP SQ|<NP-VP-.>
#
# 8 SQ|<NP-VP-.>  NP SQ|<VP-.>
#
# 8 SQ|<VP-.>  VP .
#
# 3 VP  VBG SBAR
#
# 25 SBAR  S
#
# 9 VP  NN
#
# 2 S  ADVP S|<,-NP-VP-.>
#
# 1 ADVP  RB ADVP|<IN-DT>
#
# 1 ADVP|<IN-DT>  IN DT
#
# 13 VP  VB VP
#
# 6 VP  VBN
#
# 1 FRAG  WHNP FRAG|<:-NP-.>
#
# 2 FRAG|<:-NP-.>  : FRAG|<NP-.>
#
# 1 FRAG|<NP-.>  NP .
#
# 8 NP  DT JJ
#
# 1 VP  VBZ VP|<RB-NP-PP>
#
# 1 VP|<RB-NP-PP>  RB VP|<NP-PP>
#
# 1 PP  IN SBAR
#
# 5 SBAR  WHADVP S
#
# 8 NP  JJ NNS
#
# 3 NP  DT NP|<ADJP-NN>
#
# 3 NP|<ADJP-NN>  ADJP NN
#
# 2 ADJP  CD NN
#
# 4 VP  MD VP|<RB-VP>
#
# 25 VP|<RB-VP>  RB VP
#
# 2 VP  VBZ VP|<RB-VP>
#
# 2 SQ  MD SQ|<NP-VP-.>
#
# 1 SQ|<VP-.>  VP ..
#
# 6 VP  VP VP|<CC-VP>
#
# 9 VP|<CC-VP>  CC VP
#
# 3 VP  VB VP|<NP-SBAR>
#
# 4 VP|<NP-SBAR>  NP SBAR
#
# 1 S  NNP S|<,-SBAR-,-NP-VP-.>
#
# 1 S|<,-SBAR-,-NP-VP-.>  ,, S|<SBAR-,-NP-VP-.>
#
# 1 S|<SBAR-,-NP-VP-.>  SBAR S|<,-NP-VP-.>
#
# 1 SBAR  IN SBAR|<NN-S>
#
# 1 SBAR|<NN-S>  NN S
#
# 1 VP  S VP|<:-NP>
#
# 35 VP  TO VP
#
# 1 VP|<:-NP>  : NP
#
# 3 NP  NN NN
#
# 1 VP  NNS S
#
# 1 VP  VB VP|<NP-NP-,-INTJ>
#
# 1 VP|<NP-NP-,-INTJ>  NP VP|<NP-,-INTJ>
#
# 14 NP  PRP$ NNS
#
# 2 VP|<NP-,-INTJ>  NP VP|<,-INTJ>
#
# 5 NP  NP NP
#
# 2 NP  CD NNS
#
# 2 VP|<,-INTJ>  ,, INTJ
#
# 6 INTJ  NN .
#
# 1 SQ  VBP SQ|<NP-ADJP-.>
#
# 2 SQ|<NP-ADJP-.>  NP SQ|<ADJP-.>
#
# 2 SQ|<ADJP-.>  ADJP .
#
# 3 ADJP  RB
#
# 6 NP  NP NP|<ADJP-.>
#
# 16 ADJP  RB JJ
#
# 11 VP  VBN PP
#
# 1 S  INTJ S|<,-INTJ-,-CC-RB-NP-,-NP-VP-.>
#
# 37 INTJ  UH
#
# 1 S|<,-INTJ-,-CC-RB-NP-,-NP-VP-.>  ,, S|<INTJ-,-CC-RB-NP-,-NP-VP-.>
#
# 1 S|<INTJ-,-CC-RB-NP-,-NP-VP-.>  INTJ S|<,-CC-RB-NP-,-NP-VP-.>
#
# 1 INTJ  INTJ INTJ|<,-NP-ADVP>
#
# 1 INTJ|<,-NP-ADVP>  ,, INTJ|<NP-ADVP>
#
# 1 INTJ|<NP-ADVP>  NP ADVP
#
# 1 S|<,-CC-RB-NP-,-NP-VP-.>  ,, S|<CC-RB-NP-,-NP-VP-.>
#
# 1 S|<CC-RB-NP-,-NP-VP-.>  CC S|<RB-NP-,-NP-VP-.>
#
# 1 S|<RB-NP-,-NP-VP-.>  RB S|<NP-,-NP-VP-.>
#
# 1 S|<NP-,-NP-VP-.>  NP S|<,-NP-VP-.>
#
# 2 NP  WDT
#
# 2 VP  POS NP
#
# 1 S  INTJ S|<,-INTJ-,-NP-VP-:>
#
# 1 S|<,-INTJ-,-NP-VP-:>  ,, S|<INTJ-,-NP-VP-:>
#
# 1 S|<INTJ-,-NP-VP-:>  INTJ S|<,-NP-VP-:>
#
# 3 S|<,-NP-VP-:>  ,, S|<NP-VP-:>
#
# 5 S|<NP-VP-:>  NP S|<VP-:>
#
# 1 SQ  MD SQ|<NP-VP-.-.>
#
# 1 SQ|<NP-VP-.-.>  NP SQ|<VP-.-.>
#
# 1 SQ|<VP-.-.>  VP SQ|<.-.>
#
# 3 VP  VBZ S
#
# 1 SQ|<.-.>  . .
#
# 1 S  CC S|<ADVP-PP-NP-VP-.>
#
# 1 S|<ADVP-PP-NP-VP-.>  ADVP S|<PP-NP-VP-.>
#
# 1 S|<PP-NP-VP-.>  PP S|<NP-VP-.>
#
# 1 VP  VBP VP|<RB-ADJP>
#
# 2 VP|<RB-ADJP>  RB ADJP
#
# 3 FRAG  INTJ FRAG|<,-INTJ-:>
#
# 3 FRAG|<,-INTJ-:>  ,, FRAG|<INTJ-:>
#
# 3 FRAG|<INTJ-:>  INTJ :
#
# 1 S  IN S|<NP-VP-:>
#
# 1 VP  VB VP|<NP-ADVP-ADVP>
#
# 1 VP|<NP-ADVP-ADVP>  NP VP|<ADVP-ADVP>
#
# 3 VP|<ADVP-ADVP>  ADVP ADVP
#
# 1 VP  WRB VP|<NP-:-S>
#
# 1 VP|<NP-:-S>  NP VP|<:-S>
#
# 1 VP|<:-S>  : S
#
# 1 VP  VBD VP|<NP-ADVP>
#
# 11 INTJ  DT
#
# 13 VP  VB S
#
# 1 FRAG  INTJ FRAG|<,-ADJP-.>
#
# 3 FRAG|<,-ADJP-.>  ,, FRAG|<ADJP-.>
#
# 1 FRAG|<ADJP-.>  ADJP .
#
# 2 ADJP  NN
#
# 1 VP  MD VP|<ADVP-VP>
#
# 7 VP|<ADVP-VP>  ADVP VP
#
# 1 SBARQ  WHNP SBARQ|<,-VP-.>
#
# 1 SBARQ|<,-VP-.>  ,, SBARQ|<VP-.>
#
# 2 SBARQ|<VP-.>  VP .
#
# 1 VP  VBD PP
#
# 1 NP  DT NP|<NN-VBG-NNS>
#
# 1 NP|<NN-VBG-NNS>  NN NP|<VBG-NNS>
#
# 1 NP|<VBG-NNS>  VBG NNS
#
# 1 FRAG  INTJ FRAG|<,-WHADVP-RB-.>
#
# 1 FRAG|<,-WHADVP-RB-.>  ,, FRAG|<WHADVP-RB-.>
#
# 1 FRAG|<WHADVP-RB-.>  WHADVP FRAG|<RB-.>
#
# 2 FRAG|<RB-.>  RB .
#
# 2 VP  VBG VP|<PRT-NP>
#
# 2 VP|<PRT-NP>  PRT NP
#
# 18 PRT  RP
#
# 2 NP  PRP$ JJ
#
# 2 S1  SINV
#
# 1 SINV  ADVP SINV|<VP-NP-.>
#
# 2 SINV|<VP-NP-.>  VP SINV|<NP-.>
#
# 5 VP  VBZ
#
# 2 SINV|<NP-.>  NP ..
#
# 6 NP  NP NP|<:-NP>
#
# 9 NP  CD
#
# 6 NP|<:-NP>  : NP
#
# 2 NP  CD NN
#
# 1 SINV  NP SINV|<:-ADVP-VP-NP-.>
#
# 1 SINV|<:-ADVP-VP-NP-.>  : SINV|<ADVP-VP-NP-.>
#
# 1 SINV|<ADVP-VP-NP-.>  ADVP SINV|<VP-NP-.>
#
# 1 NP  PRP$ NP|<CD-NN>
#
# 1 NP|<CD-NN>  CD NN
#
# 1 S  ADVP S|<:-NP-VP-.>
#
# 3 S|<:-NP-VP-.>  : S|<NP-VP-.>
#
# 8 VP  VBZ SBAR
#
# 1 VP  VBZ VP|<RB-ADJP>
#
# 1 INTJ  NNP INTJ|<RB-.>
#
# 1 INTJ|<RB-.>  RB .
#
# 2 VP  VBZ RB
#
# 1 S  INTJ S|<,-S-,-S-.>
#
# 1 S|<,-S-,-S-.>  ,, S|<S-,-S-.>
#
# 2 S|<S-,-S-.>  S S|<,-S-.>
#
# 6 VP  VB ADVP
#
# 5 S|<,-S-.>  ,, S|<S-.>
#
# 2 VP  VBZ ADJP
#
# 1 VP  VBG ADJP
#
# 1 S  INTJ S|<,-S-:-S-.>
#
# 2 S|<,-S-:-S-.>  ,, S|<S-:-S-.>
#
# 2 S|<S-:-S-.>  S S|<:-S-.>
#
# 3 VP  VBP RB
#
# 11 S|<:-S-.>  : S|<S-.>
#
# 1 VP  VB VP|<ADJP-PP>
#
# 4 VP|<ADJP-PP>  ADJP PP
#
# 1 ADJP  VBN JJ
#
# 5 S  S S|<:-S-.>
#
# 4 S  INTJ S|<,-NP-VP>
#
# 6 S|<,-NP-VP>  ,, S|<NP-VP>
#
# 10 S|<NP-VP>  NP VP
#
# 7 VP  VBZ PP
#
# 13 VP  VBP VP|<RB-VP>
#
# 7 S  INTJ S|<,-VP-.>
#
# 14 S|<,-VP-.>  ,, S|<VP-.>
#
# 1 NP  JJ NP|<DT-NN>
#
# 3 NP|<DT-NN>  DT NN
#
# 5 VP  VBP ADJP
#
# 1 S  INTJ S|<,-VP-:>
#
# 1 S|<,-VP-:>  ,, S|<VP-:>
#
# 3 VP  VBP VP|<NP-NP>
#
# 8 VP|<NP-NP>  NP NP
#
# 1 SQ  INTJ SQ|<,-MD-NP-VP-.>
#
# 3 SQ|<,-MD-NP-VP-.>  ,, SQ|<MD-NP-VP-.>
#
# 3 SQ|<MD-NP-VP-.>  MD SQ|<NP-VP-.>
#
# 1 PP  PRT NP
#
# 8 PRT  IN
#
# 5 VP  VB ADJP
#
# 1 S  NP S|<,-S-:-S-.>
#
# 4 VP  VBD S
#
# 1 VP  VB VP|<PRT-PP>
#
# 4 VP|<PRT-PP>  PRT PP
#
# 1 NP  NNP POS
#
# 1 VP  VBN VP|<NP-NP>
#
# 1 SBARQ  INTJ SBARQ|<,-WHADVP-SQ-.>
#
# 3 SBARQ|<,-WHADVP-SQ-.>  ,, SBARQ|<WHADVP-SQ-.>
#
# 3 SBARQ|<WHADVP-SQ-.>  WHADVP SBARQ|<SQ-.>
#
# 4 SQ  VBZ NP
#
# 8 NP  PRP$ NP|<JJ-NN>
#
# 1 NP  NNP ..
#
# 2 VP  VBP SBAR
#
# 1 VP  VP VP|<NN-VP>
#
# 1 VP  RB VP|<VBG-NP>
#
# 1 VP|<VBG-NP>  VBG NP
#
# 1 VP|<NN-VP>  NN VP
#
# 1 SQ  NNP SQ|<,-VBZ-RB-NP-NP-.>
#
# 1 SQ|<,-VBZ-RB-NP-NP-.>  ,, SQ|<VBZ-RB-NP-NP-.>
#
# 1 SQ|<VBZ-RB-NP-NP-.>  VBZ SQ|<RB-NP-NP-.>
#
# 1 SQ|<RB-NP-NP-.>  RB SQ|<NP-NP-.>
#
# 2 SQ|<NP-NP-.>  NP SQ|<NP-.>
#
# 7 NP  EX
#
# 4 SQ|<NP-.>  NP .
#
# 1 FRAG  INTJ FRAG|<,-NP-ADVP-.>
#
# 12 INTJ  NNP
#
# 1 FRAG|<,-NP-ADVP-.>  ,, FRAG|<NP-ADVP-.>
#
# 1 FRAG|<NP-ADVP-.>  NP FRAG|<ADVP-.>
#
# 1 FRAG|<ADVP-.>  ADVP ..
#
# 1 ADVP  RB RB
#
# 1 FRAG  RB FRAG|<IN-DT-.>
#
# 1 FRAG|<IN-DT-.>  IN FRAG|<DT-.>
#
# 1 FRAG|<DT-.>  DT ..
#
# 14 S  VP ..
#
# 2 INTJ  RB ..
#
# 1 SQ  VBZ SQ|<NP-ADVP>
#
# 2 SQ|<NP-ADVP>  NP ADVP
#
# 8 NP  IN
#
# 1 VP  RB VP
#
# 1 FRAG  WRB .
#
# 4 NP  VB
#
# 1 PP  ADVP PP|<IN-NP>
#
# 1 ADVP  DT
#
# 1 PP|<IN-NP>  IN NP
#
# 4 NP  NNP NP|<NN-.>
#
# 17 NP|<NN-.>  NN .
#
# 1 NP  NP NP|<,-NN-.>
#
# 1 NP|<,-NN-.>  ,, NP|<NN-.>
#
# 3 NP|<NN-.>  NN ..
#
# 1 SBARQ  WHNP SBARQ|<S-.>
#
# 1 WHNP  WP VBD
#
# 1 VP  JJ VP|<PP-PP>
#
# 4 VP|<PP-PP>  PP PP
#
# 1 PP  IN RB
#
# 4 NP  NP NP|<NP-.>
#
# 4 NP|<NP-.>  NP ..
#
# 2 NP  VBD CD
#
# 3 NP  NP NP|<:-NP-.>
#
# 3 NP|<:-NP-.>  : NP|<NP-.>
#
# 5 NP|<NP-.>  NP .
#
# 4 NP  NP ADJP
#
# 2 VP  VBP VP|<ADVP-VP>
#
# 1 S  NP S|<``-NP-''>
#
# 1 S|<``-NP-''>  `` S|<NP-''>
#
# 1 S|<NP-''>  NP ''
#
# 1 VP  VB VP|<``-NP-POS>
#
# 1 VP|<``-NP-POS>  `` VP|<NP-POS>
#
# 1 VP|<NP-POS>  NP POS
#
# 1 S  INTJ S|<,-NP-VP-.-''>
#
# 1 S|<,-NP-VP-.-''>  ,, S|<NP-VP-.-''>
#
# 1 S|<NP-VP-.-''>  NP S|<VP-.-''>
#
# 1 S|<VP-.-''>  VP S|<.-''>
#
# 4 VP  VBD VP|<RB-VP>
#
# 9 VP  VB SBAR
#
# 6 VP  VBD VP
#
# 4 VP  VBN S
#
# 1 S  `` NP
#
# 1 S|<.-''>  .. ''
#
# 1 VP  VB VP|<S-,-SQ>
#
# 1 VP|<S-,-SQ>  S VP|<,-SQ>
#
# 2 VP  VB PRT
#
# 1 VP|<,-SQ>  ,, SQ
#
# 1 SQ  VBD NP
#
# 1 S  S S|<,-''-CC-S-:>
#
# 1 NP  DT NP|<``-JJ-NN>
#
# 1 NP|<``-JJ-NN>  `` NP|<JJ-NN>
#
# 1 S|<,-''-CC-S-:>  ,, S|<''-CC-S-:>
#
# 1 S|<''-CC-S-:>  '' S|<CC-S-:>
#
# 2 S|<CC-S-:>  CC S|<S-:>
#
# 2 S|<S-:>  S :
#
# 2 S  PP S|<NP-VP>
#
# 4 VP  VBD
#
# 1 S  SBAR S|<VP-.>
#
# 2 PP  TO
#
# 2 S  NP S|<ADVP-VP>
#
# 2 S|<ADVP-VP>  ADVP VP
#
# 1 S  INTJ S|<,-NP-VP-:>
#
# 20 VP  VBP NP
#
# 2 NP  VBG
#
# 1 FRAG  INTJ FRAG|<,-INTJ-,-ADJP-.>
#
# 1 INTJ  UH NN
#
# 2 FRAG|<,-INTJ-,-ADJP-.>  ,, FRAG|<INTJ-,-ADJP-.>
#
# 2 FRAG|<INTJ-,-ADJP-.>  INTJ FRAG|<,-ADJP-.>
#
# 9 INTJ  NN
#
# 2 FRAG|<ADJP-.>  ADJP ..
#
# 1 WHADVP  DT WHADVP|<POS-WHADVP>
#
# 1 WHADVP|<POS-WHADVP>  POS WHADVP
#
# 1 SQ  SQ SQ|<,-INTJ>
#
# 1 SQ|<,-INTJ>  ,, INTJ
#
# 4 INTJ  VB
#
# 1 FRAG  IN FRAG|<S-.>
#
# 1 FRAG|<S-.>  S .
#
# 1 VP  NN VP|<''-NP-:-IN-''-NN-''-PP>
#
# 1 VP|<''-NP-:-IN-''-NN-''-PP>  '' VP|<NP-:-IN-''-NN-''-PP>
#
# 1 VP|<NP-:-IN-''-NN-''-PP>  NP VP|<:-IN-''-NN-''-PP>
#
# 1 VP|<:-IN-''-NN-''-PP>  : VP|<IN-''-NN-''-PP>
#
# 1 VP|<IN-''-NN-''-PP>  IN VP|<''-NN-''-PP>
#
# 1 VP|<''-NN-''-PP>  '' VP|<NN-''-PP>
#
# 1 VP|<NN-''-PP>  NN VP|<''-PP>
#
# 1 VP|<''-PP>  '' PP
#
# 6 PP  IN PP
#
# 3 NP  JJ NP|<NN-NN>
#
# 2 WHNP  WDT
#
# 1 NP  DT NP|<JJ-DT-POS-JJ-NNS>
#
# 1 NP|<JJ-DT-POS-JJ-NNS>  JJ NP|<DT-POS-JJ-NNS>
#
# 1 NP|<DT-POS-JJ-NNS>  DT NP|<POS-JJ-NNS>
#
# 1 NP|<POS-JJ-NNS>  POS NP|<JJ-NNS>
#
# 1 S1  SBAR
#
# 1 SBAR  IN SBAR|<S-:>
#
# 1 SBAR|<S-:>  S :
#
# 2 VP  VBZ VP|<ADVP-VP>
#
# 2 VP  VBG S
#
# 3 S  NP S|<,-NP-VP-.>
#
# 2 VP  VBZ VP|<NP-ADVP>
#
# 1 NP  DT NP|<RB-VBP>
#
# 1 NP|<RB-VBP>  RB VBP
#
# 1 ADVP  RP RB
#
# 1 FRAG  INTJ FRAG|<:-WHADVP-SQ-.>
#
# 1 FRAG|<:-WHADVP-SQ-.>  : FRAG|<WHADVP-SQ-.>
#
# 1 FRAG|<WHADVP-SQ-.>  WHADVP FRAG|<SQ-.>
#
# 1 FRAG|<SQ-.>  SQ .
#
# 1 SQ  NN SQ|<NP-VP>
#
# 1 SBARQ  SBAR SBARQ|<,-NP-.>
#
# 1 SBAR  WHADVP SQ
#
# 3 SQ  VB SQ|<NP-VP>
#
# 1 SBARQ|<,-NP-.>  ,, SBARQ|<NP-.>
#
# 1 SBARQ|<NP-.>  NP ..
#
# 1 NP  VB NN
#
# 11 NP  NP NP|<,-NP>
#
# 11 NP|<,-NP>  ,, NP
#
# 1 SQ  S SQ
#
# 2 NP  NP NP|<PP-.>
#
# 2 NP|<PP-.>  PP .
#
# 1 NP  DT WP
#
# 1 NP  DT NP|<NNP-.>
#
# 1 NP|<NNP-.>  NNP ..
#
# 3 SQ  VBP NP
#
# 3 VP  VBD SBAR
#
# 4 VP  NN PP
#
# 1 NP  NP PRN
#
# 1 NP  DT PRP
#
# 1 PRN  : PRN|<S-:>
#
# 1 PRN|<S-:>  S :
#
# 1 SBAR  WHPP NP
#
# 1 WHPP  IN WHNP
#
# 1 NP  DT NP|<NN-NNS>
#
# 1 NP|<NN-NNS>  NN NNS
#
# 1 S  UH S|<ADVP-NP-VP-.>
#
# 4 S|<ADVP-NP-VP-.>  ADVP S|<NP-VP-.>
#
# 1 VP  VP VP|<,-S>
#
# 5 VP|<,-S>  ,, S
#
# 1 VP  VBG VP|<NP-PP-ADVP>
#
# 1 VP|<NP-PP-ADVP>  NP VP|<PP-ADVP>
#
# 3 VP|<PP-ADVP>  PP ADVP
#
# 1 VP  VBZ VP|<PP-SBAR>
#
# 1 VP|<PP-SBAR>  PP SBAR
#
# 1 PP  DT IN
#
# 1 SBAR  IN SBAR|<JJ-S>
#
# 1 SBAR|<JJ-S>  JJ S
#
# 2 VP  MD
#
# 2 NP  DT CD
#
# 1 VP  NN ADVP
#
# 1 SBARQ  ADVP SBARQ|<WHNP-SQ-.>
#
# 5 SBARQ|<WHNP-SQ-.>  WHNP SBARQ|<SQ-.>
#
# 2 VP  VBP VP|<NP-PP-S>
#
# 2 VP|<NP-PP-S>  NP VP|<PP-S>
#
# 3 VP|<PP-S>  PP S
#
# 1 NP  VBZ
#
# 8 NP  JJ NN
#
# 2 INTJ  UH ..
#
# 2 S  CC S|<NP-VP-.>
#
# 2 NP  PDT NP|<DT-NN>
#
# 9 VP  VBP S
#
# 3 NP  DT NP|<JJ-JJ-NN>
#
# 3 NP|<JJ-JJ-NN>  JJ NP|<JJ-NN>
#
# 1 FRAG  IN FRAG|<NP-,-:>
#
# 1 FRAG|<NP-,-:>  NP FRAG|<,-:>
#
# 1 NP  ADJP NNS
#
# 1 FRAG|<,-:>  ,, :
#
# 3 VP  NNP ADJP
#
# 1 FRAG  : FRAG|<CC-PP-PP-:>
#
# 1 FRAG|<CC-PP-PP-:>  CC FRAG|<PP-PP-:>
#
# 1 FRAG|<PP-PP-:>  PP FRAG|<PP-:>
#
# 1 ADJP  CD ADJP|<:-NNS>
#
# 1 ADJP|<:-NNS>  : NNS
#
# 1 FRAG|<PP-:>  PP :
#
# 1 NP  JJR
#
# 1 VP  NN VP|<NP-S>
#
# 3 VP|<NP-S>  NP S
#
# 1 NP  NP NP|<,-INTJ-:-SBARQ-.>
#
# 1 NP|<,-INTJ-:-SBARQ-.>  ,, NP|<INTJ-:-SBARQ-.>
#
# 1 NP|<INTJ-:-SBARQ-.>  INTJ NP|<:-SBARQ-.>
#
# 1 NP|<:-SBARQ-.>  : NP|<SBARQ-.>
#
# 1 NP|<SBARQ-.>  SBARQ .
#
# 1 SBARQ  WHNP SQ
#
# 1 SQ  VBZ SQ|<NP-VP>
#
# 1 SQ  INTJ SQ|<,-''-WHADVP-SQ-.>
#
# 1 SQ|<,-''-WHADVP-SQ-.>  ,, SQ|<''-WHADVP-SQ-.>
#
# 1 SQ|<''-WHADVP-SQ-.>  '' SQ|<WHADVP-SQ-.>
#
# 1 SQ|<WHADVP-SQ-.>  WHADVP SQ|<SQ-.>
#
# 1 WHADVP  NN
#
# 2 SQ|<SQ-.>  SQ .
#
# 1 SQ  VBD SQ|<NP-VP>
#
# 4 VP  VB VP|<NP-ADVP>
#
# 1 NP  NP NP|<PP-,>
#
# 1 NP|<PP-,>  PP ,,
#
# 1 NP  NP NP|<,-VP>
#
# 1 NP  DT NP|<NN-VBG-NN>
#
# 1 NP|<NN-VBG-NN>  NN NP|<VBG-NN>
#
# 1 NP|<VBG-NN>  VBG NN
#
# 1 NP|<,-VP>  ,, VP
#
# 2 VP  VP SBAR
#
# 1 VP  VBD VP|<PP-PP>
#
# 1 PP  RB NP
#
# 1 NP  NP NP|<,-NP-,>
#
# 1 S  PRN S|<:-S-.>
#
# 3 PRN  S
#
# 5 VP  NNP
#
# 1 VP  VBG VP|<PP-S>
#
# 1 NP  NNP NP|<NN-NN>
#
# 1 PP  PP PP|<,-RB-PP>
#
# 1 PP|<,-RB-PP>  ,, PP|<RB-PP>
#
# 1 PP|<RB-PP>  RB PP
#
# 7 S  ADVP S|<NP-VP-.>
#
# 1 VP  VB VP|<S-NN-SBAR>
#
# 1 VP|<S-NN-SBAR>  S VP|<NN-SBAR>
#
# 1 VP  S VP|<RB-POS>
#
# 1 VP  TO VP|<VB-NP>
#
# 3 VP|<VB-NP>  VB NP
#
# 1 VP|<RB-POS>  RB POS
#
# 1 VP|<NN-SBAR>  NN SBAR
#
# 2 VP  VBD VP|<NP-PP>
#
# 5 VP  NNP PRT
#
# 1 VP  VBP VP|<,-S>
#
# 1 S  SBAR S|<NP-VP>
#
# 1 VP  VBD VP|<ADVP-S>
#
# 1 VP|<ADVP-S>  ADVP S
#
# 4 ADVP  IN
#
# 1 VP  NN VP|<''-NP-VP>
#
# 1 VP|<''-NP-VP>  '' VP|<NP-VP>
#
# 1 VP|<NP-VP>  NP VP
#
# 1 SBAR  RB SBAR|<IN-S>
#
# 2 SBAR|<IN-S>  IN S
#
# 1 S  INTJ S|<,-ADVP-NP-VP-.>
#
# 2 S|<,-ADVP-NP-VP-.>  ,, S|<ADVP-NP-VP-.>
#
# 1 VP  NNP VP|<CC-VB-NP>
#
# 2 VP|<CC-VB-NP>  CC VP|<VB-NP>
#
# 2 VP  VBG VP
#
# 1 FRAG  INTJ FRAG|<,-WHNP-NP-PRT-.>
#
# 1 FRAG|<,-WHNP-NP-PRT-.>  ,, FRAG|<WHNP-NP-PRT-.>
#
# 1 FRAG|<WHNP-NP-PRT-.>  WHNP FRAG|<NP-PRT-.>
#
# 1 FRAG|<NP-PRT-.>  NP FRAG|<PRT-.>
#
# 1 FRAG|<PRT-.>  PRT ..
#
# 1 PRT  NN
#
# 1 SQ  NNP SQ|<NP-ADVP-NP-.>
#
# 1 SQ|<NP-ADVP-NP-.>  NP SQ|<ADVP-NP-.>
#
# 1 NP  NP NP|<ADVP-,-VBD-NP>
#
# 1 NP|<ADVP-,-VBD-NP>  ADVP NP|<,-VBD-NP>
#
# 1 ADVP  ADVP NP
#
# 1 NP|<,-VBD-NP>  ,, NP|<VBD-NP>
#
# 1 NP|<VBD-NP>  VBD NP
#
# 1 SQ|<ADVP-NP-.>  ADVP SQ|<NP-.>
#
# 2 NP  NP NP|<,-INTJ>
#
# 2 NP|<,-INTJ>  ,, INTJ
#
# 1 S  S S|<:-SINV-,-S-.>
#
# 2 S  NP PP
#
# 1 PP  RB
#
# 1 S|<:-SINV-,-S-.>  : S|<SINV-,-S-.>
#
# 1 S|<SINV-,-S-.>  SINV S|<,-S-.>
#
# 1 SINV  VBD SINV|<NP-VP>
#
# 1 SINV|<NP-VP>  NP VP
#
# 4 S|<S-.>  S .
#
# 1 VP  VBD VP|<RB-NP>
#
# 1 VP  VBP VP|<NP-S>
#
# 1 NP  DT NP|<ADJP-NNS>
#
# 1 NP|<ADJP-NNS>  ADJP NNS
#
# 1 ADJP  ADJP ADJP|<CC-DT-JJS>
#
# 1 ADJP|<CC-DT-JJS>  CC ADJP|<DT-JJS>
#
# 1 ADJP|<DT-JJS>  DT JJS
#
# 1 NP  PRP$ NNP
#
# 1 S  S S|<:-SQ-.>
#
# 3 S  NP ADJP
#
# 1 S|<:-SQ-.>  : S|<SQ-.>
#
# 1 S|<SQ-.>  SQ .
#
# 4 S  RB S|<VP-.>
#
# 2 VP  NNP VP|<,-NP>
#
# 8 VP|<,-NP>  ,, NP
#
# 1 NP  NP ,,
#
# 3 NP  JJ NP|<NNP-NN>
#
# 3 NP|<NNP-NN>  NNP NN
#
# 1 S  ADVP S|<VP-.>
#
# 1 VP  VBP VP|<ADVP-,-NP>
#
# 2 VP|<ADVP-,-NP>  ADVP VP|<,-NP>
#
# 1 FRAG  POS FRAG|<NNP-NP-.>
#
# 1 FRAG|<NNP-NP-.>  NNP FRAG|<NP-.>
#
# 1 NP  CC NP
#
# 10 NP  DT NP|<NN-.>
#
# 1 VP  POS ADVP
#
# 2 ADVP  RP
#
# 3 SBARQ  INTJ SBARQ|<,-WHNP-SQ-.>
#
# 3 SBARQ|<,-WHNP-SQ-.>  ,, SBARQ|<WHNP-SQ-.>
#
# 3 VP  VBD ADJP
#
# 2 ADJP  JJR
#
# 1 VP  VB VP|<PP-NP>
#
# 2 VP|<PP-NP>  PP NP
#
# 1 NP  VBP
#
# 6 NP  JJ
#
# 1 VP  VBP VP|<NP-,-S>
#
# 1 VP|<NP-,-S>  NP VP|<,-S>
#
# 1 NP  JJ NNP
#
# 2 VP  NNP VP|<PRT-ADVP>
#
# 2 VP|<PRT-ADVP>  PRT ADVP
#
# 4 S  S S|<,-CC-S-.>
#
# 1 VP  VBP VP|<ADVP-ADJP-,-NP>
#
# 1 VP|<ADVP-ADJP-,-NP>  ADVP VP|<ADJP-,-NP>
#
# 2 VP|<ADJP-,-NP>  ADJP VP|<,-NP>
#
# 4 S|<,-CC-S-.>  ,, S|<CC-S-.>
#
# 1 FRAG  INTJ FRAG|<,-VP-.>
#
# 2 FRAG|<,-VP-.>  ,, FRAG|<VP-.>
#
# 1 FRAG|<VP-.>  VP .
#
# 1 NP  RB
#
# 1 S  NNP S|<,-S-,-NP-VP-.>
#
# 1 S|<,-S-,-NP-VP-.>  ,, S|<S-,-NP-VP-.>
#
# 1 S|<S-,-NP-VP-.>  S S|<,-NP-VP-.>
#
# 1 S  PRP S|<VBP-RB>
#
# 1 S|<VBP-RB>  VBP RB
#
# 6 VP  VBN NP
#
# 1 ADJP  VBD
#
# 1 ADVP  UH
#
# 1 NP  RB NP|<DT-JJ-NN-.>
#
# 1 NP|<DT-JJ-NN-.>  DT NP|<JJ-NN-.>
#
# 1 NP|<JJ-NN-.>  JJ NP|<NN-.>
#
# 1 S  PRN S|<,-VP-.>
#
# 1 VP  NN NP
#
# 1 S  PRN S|<,-NP-VP-.>
#
# 4 INTJ  RB .
#
# 1 VP  MD NP
#
# 1 NP  WP
#
# 1 VP  NNP VP|<POS-INTJ>
#
# 1 VP|<POS-INTJ>  POS INTJ
#
# 1 VP  VP VP|<,-VP>
#
# 1 VP|<,-VP>  ,, VP
#
# 1 S  NP S|<ADVP-VP-.>
#
# 13 NP  DT NP|<NNP-NNP>
#
# 19 NP|<NNP-NNP>  NNP NNP
#
# 1 S|<ADVP-VP-.>  ADVP S|<VP-.>
#
# 1 S  FRAG S|<:-S-.>
#
# 1 FRAG  ADVP
#
# 1 ADVP  DT NN
#
# 4 S  NP NP
#
# 1 FRAG  INTJ FRAG|<,-INTJ-PRN-VP-.>
#
# 1 FRAG|<,-INTJ-PRN-VP-.>  ,, FRAG|<INTJ-PRN-VP-.>
#
# 1 FRAG|<INTJ-PRN-VP-.>  INTJ FRAG|<PRN-VP-.>
#
# 1 FRAG|<PRN-VP-.>  PRN FRAG|<VP-.>
#
# 1 PRN  ,, PRN|<S-,>
#
# 1 PRN|<S-,>  S ,,
#
# 2 FRAG|<VP-.>  VP ..
#
# 1 VP  VBG VP|<ADVP-ADVP>
#
# 1 VP  VBP NNS
#
# 1 VP  NNP VP|<ADVP-ADVP>
#
# 5 VP  VBZ VP
#
# 2 VP  VBG PP
#
# 4 VP  VB VP|<NP-PRT>
#
# 6 VP|<NP-PRT>  NP PRT
#
# 1 SQ  S SQ|<,-SQ-.>
#
# 1 SQ|<,-SQ-.>  ,, SQ|<SQ-.>
#
# 5 VP  NNP NP
#
# 2 VP  NNP VP|<NP-ADVP>
#
# 5 NP  PRP$
#
# 4 ADVP  NN
#
# 1 FRAG  NNP FRAG|<RB-NP-.>
#
# 2 FRAG|<RB-NP-.>  RB FRAG|<NP-.>
#
# 1 VP  VBD VP|<NP-PRT-PP>
#
# 2 VP|<NP-PRT-PP>  NP VP|<PRT-PP>
#
# 1 VP  VBD VP|<RB-:-INTJ>
#
# 1 VP|<RB-:-INTJ>  RB VP|<:-INTJ>
#
# 1 VP|<:-INTJ>  : INTJ
#
# 1 S  CC S|<S-,-S-.>
#
# 1 VP  VBZ VP|<RB-NP>
#
# 1 S  CC S|<NP-:-CC-S-.>
#
# 1 S|<NP-:-CC-S-.>  NP S|<:-CC-S-.>
#
# 1 S|<:-CC-S-.>  : S|<CC-S-.>
#
# 1 VP  VB VP|<NP-PRT-PP>
#
# 1 INTJ  INTJ INTJ|<:-INTJ-.>
#
# 1 INTJ|<:-INTJ-.>  : INTJ|<INTJ-.>
#
# 1 INTJ|<INTJ-.>  INTJ ..
#
# 1 FRAG  INTJ FRAG|<,-INTJ-,-NP-.>
#
# 1 FRAG|<,-INTJ-,-NP-.>  ,, FRAG|<INTJ-,-NP-.>
#
# 1 FRAG|<INTJ-,-NP-.>  INTJ FRAG|<,-NP-.>
#
# 1 INTJ  INTJ INTJ|<,-NP>
#
# 1 INTJ|<,-NP>  ,, NP
#
# 4 FRAG|<,-NP-.>  ,, FRAG|<NP-.>
#
# 1 ADJP  RBR
#
# 4 S1  ADJP
#
# 1 ADJP  JJ ADJP|<,-JJ-.>
#
# 1 ADJP|<,-JJ-.>  ,, ADJP|<JJ-.>
#
# 1 ADJP|<JJ-.>  JJ ..
#
# 2 ADJP  JJ .
#
# 2 PP  IN S
#
# 1 SQ  IN SQ|<ADVP-.>
#
# 1 SQ|<ADVP-.>  ADVP .
#
# 1 VP  VB VP|<NP-,-WHNP-SQ>
#
# 1 VP|<NP-,-WHNP-SQ>  NP VP|<,-WHNP-SQ>
#
# 1 VP|<,-WHNP-SQ>  ,, VP|<WHNP-SQ>
#
# 1 VP|<WHNP-SQ>  WHNP SQ
#
# 1 S  NNP S|<,-VP-.>
#
# 1 VP  VBP VP|<NP-PRT>
#
# 1 SBARQ  CC SBARQ|<WHNP-SQ-.>
#
# 1 PP  RB PP
#
# 1 NP  RBR NP|<NNS-.>
#
# 2 NP|<NNS-.>  NNS .
#
# 2 SBARQ  ADVP SBARQ|<,-WHADVP-SQ-.>
#
# 1 NP  NNP NP|<:-:>
#
# 1 NP|<:-:>  : :
#
# 1 SQ  '' SQ|<ADVP-NP-VP-:-.>
#
# 1 SQ|<ADVP-NP-VP-:-.>  ADVP SQ|<NP-VP-:-.>
#
# 1 SQ|<NP-VP-:-.>  NP SQ|<VP-:-.>
#
# 1 SQ|<VP-:-.>  VP SQ|<:-.>
#
# 1 SQ|<:-.>  : .
#
# 1 INTJ  UH INTJ
#
# 1 SQ  INTJ SQ|<,-CC-MD-NP-RB-ADVP-VP-.>
#
# 1 SQ|<,-CC-MD-NP-RB-ADVP-VP-.>  ,, SQ|<CC-MD-NP-RB-ADVP-VP-.>
#
# 1 SQ|<CC-MD-NP-RB-ADVP-VP-.>  CC SQ|<MD-NP-RB-ADVP-VP-.>
#
# 1 SQ|<MD-NP-RB-ADVP-VP-.>  MD SQ|<NP-RB-ADVP-VP-.>
#
# 1 SQ|<NP-RB-ADVP-VP-.>  NP SQ|<RB-ADVP-VP-.>
#
# 1 SQ|<RB-ADVP-VP-.>  RB SQ|<ADVP-VP-.>
#
# 1 SQ|<ADVP-VP-.>  ADVP SQ|<VP-.>
#
# 3 FRAG  INTJ FRAG|<,-INTJ-.>
#
# 6 FRAG|<,-INTJ-.>  ,, FRAG|<INTJ-.>
#
# 5 FRAG|<INTJ-.>  INTJ ..
#
# 1 SBARQ  WHNP SBARQ|<ADVP-VP-.>
#
# 1 SBARQ|<ADVP-VP-.>  ADVP SBARQ|<VP-.>
#
# 3 NP  NNS .
#
# 1 NP  ADJP NP|<NNS-.>
#
# 2 INTJ  NNP ..
#
# 1 FRAG  ADVP FRAG|<,-ADVP-:-,>
#
# 1 FRAG|<,-ADVP-:-,>  ,, FRAG|<ADVP-:-,>
#
# 1 FRAG|<ADVP-:-,>  ADVP FRAG|<:-,>
#
# 1 FRAG|<:-,>  : ,,
#
# 1 S1  X
#
# 1 X  IN :
#
# 1 NP  NN ..
#
# 2 S  S S|<,-S-.>
#
# 1 FRAG  CC FRAG|<ADVP-:-.>
#
# 1 FRAG|<ADVP-:-.>  ADVP FRAG|<:-.>
#
# 2 FRAG|<:-.>  : .
#
# 1 NP  PRP$ NP|<JJR-NNS>
#
# 1 NP|<JJR-NNS>  JJR NNS
#
# 1 SQ  VBP SQ|<NP-SBAR>
#
# 1 SQ|<NP-SBAR>  NP SBAR
#
# 1 VP  VBP VP|<ADJP-PP>
#
# 1 ADJP  RB RB
#
# 2 NP  PRP$ NP|<NN-.>
#
# 1 SQ  NP SQ|<,-MD-NP-VP-.>
#
# 3 VP  VP VP|<,-CC-VP>
#
# 1 VP  VB VP|<PP-PP>
#
# 3 VP|<,-CC-VP>  ,, VP|<CC-VP>
#
# 2 NP  NP NP|<,-NP-.>
#
# 2 NP|<,-NP-.>  ,, NP|<NP-.>
#
# 1 NP  DT NP|<NN-NNP-NNP>
#
# 1 NP|<NN-NNP-NNP>  NN NP|<NNP-NNP>
#
# 1 NP  NP NNS
#
# 1 NP  NNP NP|<NNP-POS>
#
# 1 NP|<NNP-POS>  NNP POS
#
# 1 NP  JJ NP|<JJ-NNS>
#
# 1 VP  VBD VP|<ADVP-TO-VP>
#
# 1 VP|<ADVP-TO-VP>  ADVP VP|<TO-VP>
#
# 1 VP|<TO-VP>  TO VP
#
# 1 VP  VP VP|<:-NP>
#
# 1 VP|<:-NP>  :: NP
#
# 1 NP  NP NP|<:-NP-:-CC-NP>
#
# 1 NP  NNP NP|<NNP-DT-NNP>
#
# 1 NP|<NNP-DT-NNP>  NNP NP|<DT-NNP>
#
# 1 NP|<DT-NNP>  DT NNP
#
# 1 NP|<:-NP-:-CC-NP>  : NP|<NP-:-CC-NP>
#
# 1 NP|<NP-:-CC-NP>  NP NP|<:-CC-NP>
#
# 1 NP  NNP VBD
#
# 1 NP|<:-CC-NP>  : NP|<CC-NP>
#
# 1 NP  NP NP|<PRN-NN-SBAR>
#
# 1 NP  NP NP|<DT-RB>
#
# 1 NP|<DT-RB>  DT RB
#
# 1 NP|<PRN-NN-SBAR>  PRN NP|<NN-SBAR>
#
# 1 PRN  PRN PRN|<IN-PRN>
#
# 1 PRN  : PRN|<RB-:-RB-PRN>
#
# 1 PRN|<RB-:-RB-PRN>  RB PRN|<:-RB-PRN>
#
# 1 PRN|<:-RB-PRN>  : PRN|<RB-PRN>
#
# 1 PRN|<RB-PRN>  RB PRN
#
# 1 PRN  : PRN|<ADJP-:>
#
# 1 PRN|<ADJP-:>  ADJP :
#
# 1 ADJP  VB
#
# 1 PRN|<IN-PRN>  IN PRN
#
# 1 PRN  : PRN|<NNP-:>
#
# 1 PRN|<NNP-:>  NNP :
#
# 1 NP|<NN-SBAR>  NN SBAR
#
# 1 SBAR  SBAR SBAR|<CC-SBAR>
#
# 1 SBAR  SBAR SBAR|<,-SBAR>
#
# 2 VP  VBD VP|<ADVP-VP>
#
# 1 SBAR|<,-SBAR>  ,, SBAR
#
# 1 VP  VBN VP|<PRT-PP>
#
# 2 NP  DT NP|<JJ-NNP>
#
# 2 NP|<JJ-NNP>  JJ NNP
#
# 1 SBAR|<CC-SBAR>  CC SBAR
#
# 1 SBAR  SBAR SBAR|<:-CC-NP>
#
# 1 VP  ADVP VP|<JJ-NP-PP>
#
# 1 VP|<JJ-NP-PP>  JJ VP|<NP-PP>
#
# 1 SBAR|<:-CC-NP>  : SBAR|<CC-NP>
#
# 1 SBAR|<CC-NP>  CC NP
#
# 1 NP  DT NP|<ADVP-VBN-S>
#
# 1 NP|<ADVP-VBN-S>  ADVP NP|<VBN-S>
#
# 1 NP|<VBN-S>  VBN S
#
# 2 S  NP
#
# 1 NP  NNP NP|<RB-:-S>
#
# 1 NP|<RB-:-S>  RB NP|<:-S>
#
# 1 NP|<:-S>  : S
#
# 1 VP  VBG VP|<:-PP>
#
# 2 VP|<:-PP>  : PP
#
# 1 PP  PP PP|<:-NP>
#
# 1 PP  IN PP|<:-NP>
#
# 2 PP|<:-NP>  : NP
#
# 1 SBAR  SBAR SBAR|<,-NP>
#
# 1 WHNP  WP$ WHNP|<NNS-CC-NNS>
#
# 1 WHNP|<NNS-CC-NNS>  NNS WHNP|<CC-NNS>
#
# 1 WHNP|<CC-NNS>  CC NNS
#
# 1 SBAR|<,-NP>  ,, NP
#
# 1 S  CC S|<NP-,-NP-,-VP-.>
#
# 1 S|<NP-,-NP-,-VP-.>  NP S|<,-NP-,-VP-.>
#
# 2 S|<,-NP-,-VP-.>  ,, S|<NP-,-VP-.>
#
# 2 S|<NP-,-VP-.>  NP S|<,-VP-.>
#
# 1 VP  ADJP VP|<:-VP>
#
# 1 ADJP  VBN
#
# 1 VP|<:-VP>  : VP
#
# 1 VP  RB VP|<ADVP-SBAR>
#
# 1 VP|<ADVP-SBAR>  ADVP SBAR
#
# 1 FRAG  INTJ FRAG|<,-ADVP-,-INTJ-.>
#
# 1 FRAG|<,-ADVP-,-INTJ-.>  ,, FRAG|<ADVP-,-INTJ-.>
#
# 1 FRAG|<ADVP-,-INTJ-.>  ADVP FRAG|<,-INTJ-.>
#
# 1 VP  NN VP|<,-NP>
#
# 1 VP  VBZ VP|<ADVP-NP>
#
# 1 VP|<ADVP-NP>  ADVP NP
#
# 1 VP  VBP VP|<NP-ADJP-PP>
#
# 1 VP|<NP-ADJP-PP>  NP VP|<ADJP-PP>
#
# 1 ADJP  VBP
#
# 1 S  VP :
#
# 1 PP  TO PP|<NP-.>
#
# 1 PP|<NP-.>  NP ..
#
# 2 NP  NNP NNS
#
# 2 VP  NN ADJP
#
# 1 FRAG  PP FRAG|<:-NP-.>
#
# 1 VP  VBP VP|<ADVP-ADVP-PP>
#
# 1 VP|<ADVP-ADVP-PP>  ADVP VP|<ADVP-PP>
#
# 1 NP  JJ NP|<CC-NN>
#
# 1 VP  NP NP
#
# 1 PP  IN PP|<:-NN-:-JJ>
#
# 1 PP|<:-NN-:-JJ>  : PP|<NN-:-JJ>
#
# 1 PP|<NN-:-JJ>  NN PP|<:-JJ>
#
# 1 PP|<:-JJ>  : JJ
#
# 1 S  IN S
#
# 1 NP  JJ NP|<NNS-JJ>
#
# 1 NP|<NNS-JJ>  NNS JJ
#
# 1 ADJP  ADJP ADJP|<:-ADJP>
#
# 1 ADJP|<:-ADJP>  : ADJP
#
# 1 S  NP S|<RB-RB-JJ-PP>
#
# 1 S|<RB-RB-JJ-PP>  RB S|<RB-JJ-PP>
#
# 1 S|<RB-JJ-PP>  RB S|<JJ-PP>
#
# 1 S|<JJ-PP>  JJ PP
#
# 1 VP  VBG VP|<PP-NP>
#
# 1 S  INTJ VP
#
# 1 ADJP  JJ ADJP|<CC-JJ>
#
# 1 ADJP|<CC-JJ>  CC JJ
#
# 1 FRAG  CC VP
#
# 1 VP  VBZ VP|<ADJP-PP>
#
# 1 ADJP  NP ADJP|<RB-JJ>
#
# 1 ADJP|<RB-JJ>  RB JJ
#
# 4 VP  VB VP|<NP-NP>
#
# 1 S  INTJ S|<,-PP-,-VP>
#
# 1 S|<,-PP-,-VP>  ,, S|<PP-,-VP>
#
# 1 S|<PP-,-VP>  PP S|<,-VP>
#
# 1 S|<,-VP>  ,, VP
#
# 1 S  NP S|<RB-VP>
#
# 1 S|<RB-VP>  RB VP
#
# 1 NP  NNP .
#
# 2 S  SBAR S|<,-NP-VP-.>
#
# 1 VP  RB
#
# 1 VP  VBG
#
# 1 INTJ  NNP :
#
# 1 S  CC S|<VP-.>
#
# 1 S  NP S|<NP-VP-.>
#
# 1 NP  JJ NP|<NN-NP-NN-CC-NNP-VP-NN-CC-S>
#
# 1 NP|<NN-NP-NN-CC-NNP-VP-NN-CC-S>  NN NP|<NP-NN-CC-NNP-VP-NN-CC-S>
#
# 1 NP|<NP-NN-CC-NNP-VP-NN-CC-S>  NP NP|<NN-CC-NNP-VP-NN-CC-S>
#
# 1 NP|<NN-CC-NNP-VP-NN-CC-S>  NN NP|<CC-NNP-VP-NN-CC-S>
#
# 1 NP|<CC-NNP-VP-NN-CC-S>  CC NP|<NNP-VP-NN-CC-S>
#
# 1 NP|<NNP-VP-NN-CC-S>  NNP NP|<VP-NN-CC-S>
#
# 1 NP|<VP-NN-CC-S>  VP NP|<NN-CC-S>
#
# 1 NP|<NN-CC-S>  NN NP|<CC-S>
#
# 1 NP|<CC-S>  CC S
#
# 1 ADJP  ADJP NN
#
# 1 SBARQ  WHNP SBARQ|<SQ-.-.>
#
# 1 SBARQ|<SQ-.-.>  SQ SBARQ|<.-.>
#
# 1 VP  VBG ADVP
#
# 1 SBARQ|<.-.>  . .
#
# 1 FRAG  S FRAG|<,-INTJ-.>
#
# 2 INTJ  JJ NNP
#
# 1 VP  VBZ VP|<NP-PRT>
#
# 3 FRAG  INTJ FRAG|<,-NP-.>
#
# 1 S  NP S|<:-S-.>
#
# 1 NP  DT NP|<JJ-NNS>
#
# 1 FRAG  NP FRAG|<,-INTJ-.>
#
# 1 FRAG|<INTJ-.>  INTJ .
#
# 1 S  '' S|<ADVP-NP-VP-.>
#
# 1 ADVP  NNP
#
# 1 S  S S|<IN-S-.>
#
# 1 VP  NNP VP|<ADVP-,-NP-,>
#
# 1 VP|<ADVP-,-NP-,>  ADVP VP|<,-NP-,>
#
# 1 VP|<,-NP-,>  ,, VP|<NP-,>
#
# 1 VP|<NP-,>  NP ,,
#
# 1 S|<IN-S-.>  IN S|<S-.>
#
# 2 NP  NP
#
# 1 VP  VBZ VP|<NP-S>
#
# 1 NP  '' NP|<NN-.>
#
# 1 NP  VBN
#
# 1 NP  VBG NNP
#
# 1 SQ  VBZ SQ|<NP-SQ>
#
# 1 SQ|<NP-SQ>  NP SQ
#
# 1 NP  NP (
#
# 1 NP  NP NP|<PP-POS-FW-FW-FW-NNP>
#
# 1 NP|<PP-POS-FW-FW-FW-NNP>  PP NP|<POS-FW-FW-FW-NNP>
#
# 1 PP  IN PP|<PRP$-NNP-NNP>
#
# 1 PP|<PRP$-NNP-NNP>  PRP$ PP|<NNP-NNP>
#
# 1 PP|<NNP-NNP>  NNP NNP
#
# 1 NP|<POS-FW-FW-FW-NNP>  POS NP|<FW-FW-FW-NNP>
#
# 1 NP|<FW-FW-FW-NNP>  FW NP|<FW-FW-NNP>
#
# 1 NP|<FW-FW-NNP>  FW NP|<FW-NNP>
#
# 1 NP|<FW-NNP>  FW NNP
#
# 1 (  ( |<.->
#
# 1 (  VB
#
# 2 |<.->  .
#
# 1 VP  VBN VP
#
# 1 VP  VBN VP|<PP-PP>
#
# 1 S  SBAR S|<NP-VP-.>
#
# 1 NP  NN NP|<CC-NN>
#
# 1 S  S S|<,-CC-S-:>
#
# 1 S|<,-CC-S-:>  ,, S|<CC-S-:>
#
# 1 S  S S|<,-NP-VP-.>
#
# 1 SQ  NNP SQ|<NP-ADJP-.>
#
# 1 ADJP  VBP SBAR
#
# 1 S  INTJ S|<,-INTJ-,-NP-VP>
#
# 1 S|<,-INTJ-,-NP-VP>  ,, S|<INTJ-,-NP-VP>
#
# 1 S|<INTJ-,-NP-VP>  INTJ S|<,-NP-VP>
#
# 1 NP  DT NP
#
# 1 VP  VBD VP|<NP-SBAR>
#
# 1 SQ  INTJ SQ|<,-INTJ-,-MD-NP-VP-.>
#
# 1 SQ|<,-INTJ-,-MD-NP-VP-.>  ,, SQ|<INTJ-,-MD-NP-VP-.>
#
# 1 SQ|<INTJ-,-MD-NP-VP-.>  INTJ SQ|<,-MD-NP-VP-.>
#
# 3 INTJ  JJ
#
# 1 FRAG  PP FRAG|<RB-.>
#
# 1 SQ  VBP SQ|<NP-ADVP>
#
# 1 NP  NNP NP|<JJ-.>
#
# 2 NP|<JJ-.>  JJ .
#
# 1 SQ  SQ SQ|<,-S>
#
# 1 SQ  VBP VP
#
# 1 SQ|<,-S>  ,, S
#
# 1 NP  RB VBG
#
# 1 NP  NNP SYM
#
# 1 VP  S VP|<,-NP>
#
# 1 VP  VP VP|<CC-VB-NP>
#
# 1 S  S S|<,-IN-:-S-.>
#
# 1 VP  VBP VP|<NP-PP>
#
# 1 S|<,-IN-:-S-.>  ,, S|<IN-:-S-.>
#
# 1 S|<IN-:-S-.>  IN S|<:-S-.>
#
# 1 S  S S|<,-NP-CC-NP>
#
# 1 NP  NNP :
#
# 1 S|<,-NP-CC-NP>  ,, S|<NP-CC-NP>
#
# 1 S|<NP-CC-NP>  NP S|<CC-NP>
#
# 1 S|<CC-NP>  CC NP
#
# 1 NP  DT NP|<PRP$-JJ-JJ-NNS>
#
# 1 NP|<PRP$-JJ-JJ-NNS>  PRP$ NP|<JJ-JJ-NNS>
#
# 1 NP|<JJ-JJ-NNS>  JJ NP|<JJ-NNS>
#
# 1 FRAG  WHNP FRAG|<FRAG-.>
#
# 1 FRAG|<FRAG-.>  FRAG ..
#
# 1 FRAG  NP
#
# 1 VP  NN VP|<ADVP-,-NP>
#
# 1 VP  VB VP|<PP-ADVP>
#
# 1 ADVP  DT RBR
#
# 1 VP  VBP VP|<VBN-JJ-NN-IN-NN>
#
# 1 VP|<VBN-JJ-NN-IN-NN>  VBN VP|<JJ-NN-IN-NN>
#
# 1 VP|<JJ-NN-IN-NN>  JJ VP|<NN-IN-NN>
#
# 1 VP|<NN-IN-NN>  NN VP|<IN-NN>
#
# 1 VP|<IN-NN>  IN NN
#
# 1 NP  PRP VBP
#
# 1 SQ  VBZ SQ|<NP-NP-.>
#
# 1 NP  NP NP|<PP-SBAR>
#
# 1 NP  NP RB
#
# 1 NP|<PP-SBAR>  PP SBAR
#
# 1 PP  IN EX
#
# 1 S  INTJ S|<,-ADVP-VP-CC-S-.>
#
# 1 S|<,-ADVP-VP-CC-S-.>  ,, S|<ADVP-VP-CC-S-.>
#
# 1 S|<ADVP-VP-CC-S-.>  ADVP S|<VP-CC-S-.>
#
# 1 S|<VP-CC-S-.>  VP S|<CC-S-.>
#
# 1 VP  VBP ADVP
#
# 1 VP  VBN ADJP
#
# 1 ADJP  ADJP PP
#
# 1 PP  IN ADJP
#
# 1 NP  ( NP|<NN-.>
#
# 1 (  |<NNP-NNP-NNP-.->
#
# 1 |<NNP-NNP-NNP-.->  NNP |<NNP-NNP-.->
#
# 1 |<NNP-NNP-.->  NNP |<NNP-.->
#
# 1 |<NNP-.->  NNP |<.->
#
# 1 |<.->  ..
#
# 1 S  (
#
# 1 (  |<NNP-NNP-NN-.->
#
# 1 |<NNP-NNP-NN-.->  NNP |<NNP-NN-.->
#
# 1 |<NNP-NN-.->  NNP |<NN-.->
#
# 1 |<NN-.->  NN |<.->
#
# 1 S  SBAR S|<,-ADVP-NP-VP-:>
#
# 1 S|<,-ADVP-NP-VP-:>  ,, S|<ADVP-NP-VP-:>
#
# 1 S|<ADVP-NP-VP-:>  ADVP S|<NP-VP-:>
#
# 1 INTJ  DT DT
#
# 1 INTJ  NNP .
#
# 1 VP  VBP VP|<NP-,-INTJ>
#
# 2 VP  NN VP
#
# 1 INTJ  JJ INTJ|<NP-.>
#
# 1 INTJ|<NP-.>  NP .
#
# 1 NP  DT NP|<JJ-.>
#
# 1 INTJ  JJ INTJ|<VP-.>
#
# 1 INTJ|<VP-.>  VP .
#
# 1 FRAG  SYM FRAG|<:-.>
#
# 2 VP  NN S
#
# 2 NP  POS
#
# 1 S  INTJ S|<,-ADVP-,-INTJ-,-NNP-,-NNP-,-CC-PRP-VP-.>
#
# 1 S|<,-ADVP-,-INTJ-,-NNP-,-NNP-,-CC-PRP-VP-.>  ,, S|<ADVP-,-INTJ-,-NNP-,-NNP-,-CC-PRP-VP-.>
#
# 1 S|<ADVP-,-INTJ-,-NNP-,-NNP-,-CC-PRP-VP-.>  ADVP S|<,-INTJ-,-NNP-,-NNP-,-CC-PRP-VP-.>
#
# 1 S|<,-INTJ-,-NNP-,-NNP-,-CC-PRP-VP-.>  ,, S|<INTJ-,-NNP-,-NNP-,-CC-PRP-VP-.>
#
# 1 S|<INTJ-,-NNP-,-NNP-,-CC-PRP-VP-.>  INTJ S|<,-NNP-,-NNP-,-CC-PRP-VP-.>
#
# 1 S|<,-NNP-,-NNP-,-CC-PRP-VP-.>  ,, S|<NNP-,-NNP-,-CC-PRP-VP-.>
#
# 1 S|<NNP-,-NNP-,-CC-PRP-VP-.>  NNP S|<,-NNP-,-CC-PRP-VP-.>
#
# 1 S|<,-NNP-,-CC-PRP-VP-.>  ,, S|<NNP-,-CC-PRP-VP-.>
#
# 1 S|<NNP-,-CC-PRP-VP-.>  NNP S|<,-CC-PRP-VP-.>
#
# 1 S|<,-CC-PRP-VP-.>  ,, S|<CC-PRP-VP-.>
#
# 1 S|<CC-PRP-VP-.>  CC S|<PRP-VP-.>
#
# 1 S|<PRP-VP-.>  PRP S|<VP-.>
#
# 1 VP  VP VP|<,-CC-RB-VP>
#
# 1 VP|<,-CC-RB-VP>  ,, VP|<CC-RB-VP>
#
# 2 VP|<CC-RB-VP>  CC VP|<RB-VP>
#
# 1 VP  VB VP|<PP-,-S>
#
# 2 VP|<PP-,-S>  PP VP|<,-S>
#
# 1 VP  VBG VP|<NP-PP-:-PP>
#
# 1 VP|<NP-PP-:-PP>  NP VP|<PP-:-PP>
#
# 1 VP|<PP-:-PP>  PP VP|<:-PP>
#
# 1 PP  CONJP PP|<PP-,-CC-ADJP>
#
# 1 CONJP  RB RB
#
# 1 PP|<PP-,-CC-ADJP>  PP PP|<,-CC-ADJP>
#
# 1 PP|<,-CC-ADJP>  ,, PP|<CC-ADJP>
#
# 1 PP|<CC-ADJP>  CC ADJP
#
# 1 FRAG  INTJ FRAG|<,-NNP-,-NP-,-CC-NP-.>
#
# 1 FRAG|<,-NNP-,-NP-,-CC-NP-.>  ,, FRAG|<NNP-,-NP-,-CC-NP-.>
#
# 1 FRAG|<NNP-,-NP-,-CC-NP-.>  NNP FRAG|<,-NP-,-CC-NP-.>
#
# 1 FRAG|<,-NP-,-CC-NP-.>  ,, FRAG|<NP-,-CC-NP-.>
#
# 1 FRAG|<NP-,-CC-NP-.>  NP FRAG|<,-CC-NP-.>
#
# 1 FRAG|<,-CC-NP-.>  ,, FRAG|<CC-NP-.>
#
# 1 FRAG|<CC-NP-.>  CC FRAG|<NP-.>
#
# 1 S  INTJ S|<,-VP-:-.>
#
# 1 S|<,-VP-:-.>  ,, S|<VP-:-.>
#
# 1 S|<VP-:-.>  VP S|<:-.>
#
# 1 VP  VBZ VP|<PP-,-NN-CC-NN>
#
# 1 VP|<PP-,-NN-CC-NN>  PP VP|<,-NN-CC-NN>
#
# 1 VP|<,-NN-CC-NN>  ,, VP|<NN-CC-NN>
#
# 1 VP|<NN-CC-NN>  NN VP|<CC-NN>
#
# 1 VP|<CC-NN>  CC NN
#
# 1 S|<:-.>  : ..
#
# 1 INTJ  UH INTJ|<:-.>
#
# 1 INTJ|<:-.>  : ..
#
# 1 FRAG  INTJ FRAG|<,-INTJ-,-SBAR-:>
#
# 1 FRAG|<,-INTJ-,-SBAR-:>  ,, FRAG|<INTJ-,-SBAR-:>
#
# 1 FRAG|<INTJ-,-SBAR-:>  INTJ FRAG|<,-SBAR-:>
#
# 2 INTJ  INTJ INTJ|<:-INTJ>
#
# 2 INTJ  SYM
#
# 3 INTJ|<:-INTJ>  : INTJ
#
# 1 FRAG|<,-SBAR-:>  ,, FRAG|<SBAR-:>
#
# 1 FRAG|<SBAR-:>  SBAR :
#
# 2 S  NP S|<,-VP-.>
#
# 1 VP  ADVP VP|<VBN-NP>
#
# 1 VP|<VBN-NP>  VBN NP
#
# 1 VP  VBD VP|<NP-ADVP-PP>
#
# 1 VP|<NP-ADVP-PP>  NP VP|<ADVP-PP>
#
# 1 ADJP  VBD SBAR
#
# 1 VP  VBN SBAR
#
# 1 S  NP S|<,-S-,-VP-.>
#
# 1 S|<,-S-,-VP-.>  ,, S|<S-,-VP-.>
#
# 1 S|<S-,-VP-.>  S S|<,-VP-.>
#
# 1 NP  PRP$ NP|<JJS-NNS>
#
# 1 NP|<JJS-NNS>  JJS NNS
#
# 1 S  NP S|<MD-VP>
#
# 1 S|<MD-VP>  MD VP
#
# 1 VP  NN VP|<PP-ADVP>
#
# 1 S  ADVP S|<,-NP-VP-:>
#
# 1 NP  NP NP|<PP-:-.>
#
# 1 NP|<PP-:-.>  PP NP|<:-.>
#
# 1 NP|<:-.>  : ..
#
# 1 S  RB S|<NP-VP-.>
#
# 2 NP  PRP$ NP|<JJ-NNS>
#
# 1 VP  VBD VP|<ADVP-,-PP-,-S>
#
# 1 VP|<ADVP-,-PP-,-S>  ADVP VP|<,-PP-,-S>
#
# 1 ADVP  JJ
#
# 1 VP|<,-PP-,-S>  ,, VP|<PP-,-S>
#
# 1 NP  ADJP NP|<NNP-NNP>
#
# 1 VP  VBD VP|<ADVP-PP>
#
# 1 VP  VBD VP|<RB-ADJP-,-NP>
#
# 1 VP|<RB-ADJP-,-NP>  RB VP|<ADJP-,-NP>
#
# 2 ADJP  JJ S
#
# 1 NP  FW NP|<NNP-NNP-NNP>
#
# 1 NP|<NNP-NNP-NNP>  NNP NP|<NNP-NNP>
#
# 1 VP  VBD VP|<RB-ADVP-ADJP>
#
# 1 VP|<RB-ADVP-ADJP>  RB VP|<ADVP-ADJP>
#
# 1 VP|<ADVP-ADJP>  ADVP ADJP
#
# 1 ADVP  IN DT
#
# 1 FRAG  NNP FRAG|<,-NN-,-VBP-,-VBP-NNP-NNP-.>
#
# 1 FRAG|<,-NN-,-VBP-,-VBP-NNP-NNP-.>  ,, FRAG|<NN-,-VBP-,-VBP-NNP-NNP-.>
#
# 1 FRAG|<NN-,-VBP-,-VBP-NNP-NNP-.>  NN FRAG|<,-VBP-,-VBP-NNP-NNP-.>
#
# 1 FRAG|<,-VBP-,-VBP-NNP-NNP-.>  ,, FRAG|<VBP-,-VBP-NNP-NNP-.>
#
# 1 FRAG|<VBP-,-VBP-NNP-NNP-.>  VBP FRAG|<,-VBP-NNP-NNP-.>
#
# 1 FRAG|<,-VBP-NNP-NNP-.>  ,, FRAG|<VBP-NNP-NNP-.>
#
# 1 FRAG|<VBP-NNP-NNP-.>  VBP FRAG|<NNP-NNP-.>
#
# 1 FRAG|<NNP-NNP-.>  NNP FRAG|<NNP-.>
#
# 1 FRAG|<NNP-.>  NNP .
#
# 1 VP  VBD VP|<RB-PP-VBD-S>
#
# 1 VP|<RB-PP-VBD-S>  RB VP|<PP-VBD-S>
#
# 1 VP|<PP-VBD-S>  PP VP|<VBD-S>
#
# 1 NP  DT NP|<JJS-NN>
#
# 1 NP|<JJS-NN>  JJS NN
#
# 1 VP|<VBD-S>  VBD S
#
# 1 S  NP S|<VP-,-CC-S>
#
# 1 S|<VP-,-CC-S>  VP S|<,-CC-S>
#
# 3 VP  VBD PRT
#
# 2 S|<,-CC-S>  ,, S|<CC-S>
#
# 5 S|<CC-S>  CC S
#
# 1 S  S S|<,-NP-.>
#
# 1 VP  S VP|<,-CC-S>
#
# 1 VP|<,-CC-S>  ,, VP|<CC-S>
#
# 1 VP|<CC-S>  CC S
#
# 1 S  S S|<,-CC-S>
#
# 1 VP  VBD ADVP
#
# 1 S  NP S|<DT-VP>
#
# 1 S|<DT-VP>  DT VP
#
# 1 VP  VBD VP|<CC-VBD>
#
# 1 VP|<CC-VBD>  CC VBD
#
# 1 S|<,-NP-.>  ,, S|<NP-.>
#
# 1 S|<NP-.>  NP .
#
# 1 NP  VB NP|<NNP-NNP>
#
# 1 S  S S|<,-CC-S-,-CC-S-,-CC-NP-:>
#
# 3 S  S S|<CC-S>
#
# 1 VP  VBN ADVP
#
# 1 VP  NN PRT
#
# 1 S|<,-CC-S-,-CC-S-,-CC-NP-:>  ,, S|<CC-S-,-CC-S-,-CC-NP-:>
#
# 1 S|<CC-S-,-CC-S-,-CC-NP-:>  CC S|<S-,-CC-S-,-CC-NP-:>
#
# 1 S|<S-,-CC-S-,-CC-NP-:>  S S|<,-CC-S-,-CC-NP-:>
#
# 1 S|<,-CC-S-,-CC-NP-:>  ,, S|<CC-S-,-CC-NP-:>
#
# 1 S|<CC-S-,-CC-NP-:>  CC S|<S-,-CC-NP-:>
#
# 1 S|<S-,-CC-NP-:>  S S|<,-CC-NP-:>
#
# 1 S|<,-CC-NP-:>  ,, S|<CC-NP-:>
#
# 1 S|<CC-NP-:>  CC S|<NP-:>
#
# 1 S|<NP-:>  NP :
#
# 1 S  S S|<:-NP-VP-.>
#
# 1 S  NP VBZ
#
# 1 VP  VBZ VP|<,-SBAR>
#
# 1 VP|<,-SBAR>  ,, SBAR
#
# 1 PP  PP PP|<,-NNS>
#
# 1 PP  IN ADVP
#
# 1 PP|<,-NNS>  ,, NNS
#
# 1 VP  NNS SBAR
#
# 1 S  NP S|<:-NP-VP-.>
#
# 1 S  INTJ S|<,-NP-,-VP-.>
#
# 1 NP  NP NP|<,-NP-,-SBAR>
#
# 1 NP  JJ NP|<NNP-NNP>
#
# 1 NP|<,-NP-,-SBAR>  ,, NP|<NP-,-SBAR>
#
# 1 NP|<NP-,-SBAR>  NP NP|<,-SBAR>
#
# 1 NP  VBP NP|<NNP-NNP>
#
# 1 NP|<,-SBAR>  ,, SBAR
#
# 1 SBAR  WHNP
#
# 1 FRAG  INTJ FRAG|<,-INTJ-:-NP-:-INTJ-,-VP-.>
#
# 1 FRAG|<,-INTJ-:-NP-:-INTJ-,-VP-.>  ,, FRAG|<INTJ-:-NP-:-INTJ-,-VP-.>
#
# 1 FRAG|<INTJ-:-NP-:-INTJ-,-VP-.>  INTJ FRAG|<:-NP-:-INTJ-,-VP-.>
#
# 1 FRAG|<:-NP-:-INTJ-,-VP-.>  : FRAG|<NP-:-INTJ-,-VP-.>
#
# 1 FRAG|<NP-:-INTJ-,-VP-.>  NP FRAG|<:-INTJ-,-VP-.>
#
# 1 NP  NP NP|<RB-,-NNP-SYM>
#
# 1 NP|<RB-,-NNP-SYM>  RB NP|<,-NNP-SYM>
#
# 1 NP|<,-NNP-SYM>  ,, NP|<NNP-SYM>
#
# 1 NP|<NNP-SYM>  NNP SYM
#
# 1 FRAG|<:-INTJ-,-VP-.>  : FRAG|<INTJ-,-VP-.>
#
# 1 FRAG|<INTJ-,-VP-.>  INTJ FRAG|<,-VP-.>
#
# 1 INTJ  RB JJ
#
# 1 VP  ADVP VP|<VBG-ADVP>
#
# 1 VP|<VBG-ADVP>  VBG ADVP
#
# 1 FRAG  S FRAG|<,-CC-:>
#
# 1 FRAG|<,-CC-:>  ,, FRAG|<CC-:>
#
# 1 FRAG|<CC-:>  CC :
#
# 1 FRAG  INTJ FRAG|<,-INTJ-:-NP-:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>
#
# 1 FRAG|<,-INTJ-:-NP-:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>  ,, FRAG|<INTJ-:-NP-:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>
#
# 1 FRAG|<INTJ-:-NP-:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>  INTJ FRAG|<:-NP-:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>
#
# 1 INTJ  INTJ INTJ|<,-INTJ>
#
# 1 INTJ|<,-INTJ>  ,, INTJ
#
# 1 FRAG|<:-NP-:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>  : FRAG|<NP-:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>
#
# 1 FRAG|<NP-:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>  NP FRAG|<:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>
#
# 1 NP  NP ADVP
#
# 1 FRAG|<:-NP-,-INTJ-,-NP-:-INTJ-,-S-.>  : FRAG|<NP-,-INTJ-,-NP-:-INTJ-,-S-.>
#
# 1 FRAG|<NP-,-INTJ-,-NP-:-INTJ-,-S-.>  NP FRAG|<,-INTJ-,-NP-:-INTJ-,-S-.>
#
# 1 FRAG|<,-INTJ-,-NP-:-INTJ-,-S-.>  ,, FRAG|<INTJ-,-NP-:-INTJ-,-S-.>
#
# 1 FRAG|<INTJ-,-NP-:-INTJ-,-S-.>  INTJ FRAG|<,-NP-:-INTJ-,-S-.>
#
# 1 FRAG|<,-NP-:-INTJ-,-S-.>  ,, FRAG|<NP-:-INTJ-,-S-.>
#
# 1 FRAG|<NP-:-INTJ-,-S-.>  NP FRAG|<:-INTJ-,-S-.>
#
# 1 FRAG|<:-INTJ-,-S-.>  : FRAG|<INTJ-,-S-.>
#
# 1 FRAG|<INTJ-,-S-.>  INTJ FRAG|<,-S-.>
#
# 1 INTJ  NP INTJ|<:-INTJ>
#
# 1 INTJ  NN PP
#
# 1 PP  TO INTJ
#
# 1 FRAG|<,-S-.>  ,, FRAG|<S-.>
#
# 1 FRAG|<S-.>  S ..
#
# 1 S  S S|<,-NP>
#
# 1 S  S S|<:-NN-ADVP>
#
# 1 S  ADVP VP
#
# 1 S|<:-NN-ADVP>  : S|<NN-ADVP>
#
# 1 S|<NN-ADVP>  NN ADVP
#
# 1 S|<,-NP>  ,, NP
#
# 1 S  NP S|<ADJP-.>
#
# 1 S|<ADJP-.>  ADJP .
#
# 1 ADJP  VBD RB
#
# 1 S  NP S|<:-INTJ-,-ADVP-NP-VP-.>
#
# 1 S|<:-INTJ-,-ADVP-NP-VP-.>  : S|<INTJ-,-ADVP-NP-VP-.>
#
# 1 S|<INTJ-,-ADVP-NP-VP-.>  INTJ S|<,-ADVP-NP-VP-.>
#
# 1 S  PP S|<NP-VP-.>
#
# 1 SQ  NN SQ|<NP-.>
#
# 2 S  INTJ S|<VP-.>
#
# 1 ADJP  JJ PP
#
# 1 S  UH S|<VP-.>
#
# 1 ADVP  RB :
#
# 1 FRAG  CC FRAG|<PRP-.>
#
# 1 FRAG|<PRP-.>  PRP ..
#
# 1 ADVP  ADVP VP
#
# 1 ADVP  UH JJ
#
# 1 NP  NP PDT
#
# 2 NP|<ADJP-.>  ADJP ..
#
# 1 NP  MD
#
# 1 ADJP  RB ADJP|<VB-PP>
#
# 1 ADJP|<VB-PP>  VB PP
#
# 1 S  UH S|<NP-VP>
#
# 1 S  ADVP S|<,-NP-VP>
#
# 1 FRAG  ADVP FRAG|<NP-SBAR-.>
#
# 1 FRAG|<NP-SBAR-.>  NP FRAG|<SBAR-.>
#
# 1 FRAG|<SBAR-.>  SBAR ..
#
# 1 SBAR  ADVP SBAR|<IN-S>
#
# 1 VP  JJ NP
#
# 1 FRAG  NP FRAG|<,-INTJ-,-ADJP-.>
#
# 1 INTJ  DT NN
#
# 1 ADJP  DT NN
#
# 1 VP  VP VP|<CC-RB-VP>
#
# 1 NP  NN NP|<CC-NNS>
#
# 1 NP|<CC-NNS>  CC NNS
#
# 1 FRAG  INTJ FRAG|<,-CC-RB-NP-.>
#
# 1 FRAG|<,-CC-RB-NP-.>  ,, FRAG|<CC-RB-NP-.>
#
# 1 FRAG|<CC-RB-NP-.>  CC FRAG|<RB-NP-.>
